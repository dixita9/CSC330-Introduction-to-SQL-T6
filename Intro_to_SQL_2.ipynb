# %% [markdown]
# # Intro to SQL, Part 2
# **Learning Objective:**
# - Practice using functions and aggregate GROUP BY queries, especially MIN(), MAX(), AVG(), COUNT(), SUM()
# - Continue practicing SELECT statements

# %% [markdown]
# ❗**TODO:** Add a Markdown block below. Put the names of both partners there.

# %% [markdown]
# Below is the ERD for the Database we will be practicing with. (Chinook.db)
#
# ![chinook_schematic.jpeg](attachment:chinook_schematic.jpeg)

# %% [markdown]
# ## Setup
#
# *This is already done for you.* First, we install the python requirements from **requirements.txt**. There's lot of libraries, but most importantly, this installs the  **ipython-sql** library that enables SQL execution in Jupyter Notebooks and an older version of SQLAlchemy (1.4.46) that works with Codespaces.
#
# ❗ The command ```**%load_ext sql**``` is used to activate sql in Jupyter.
#
# ❗ The command ```**%sql sqlite:///<database_name>.db**``` is used to select the working database. (Note 3 slashes!)

# %%
# Start the Jupyter SQL engine, connecting to a SQLite database 
# %reload_ext sql 
# %sql sqlite:///chinook.db

# %% [markdown]
# # Exercises - GROUP BY

# %% [markdown]
# #### Ex. 1 - COUNT()
# How many tracks did each composer write? Show the name of the composer and the number of songs. (in Tracks table)

# %%
# %%sql
# -- Write Your Query here
# SELECT composer, COUNT(name) FROM tracks GROUP BY composer
# Out:
#  * sqlite:///chinook.db
# Done.
# [(None, 978),
#  ('A. F. Iommi, W. Ward, T. Butler, J. Osbourne', 3),
#  ('A. Jamal', 1),
#  ('A.Bouchard/J.Bouchard/S.Pearlman', 1),
#  ('A.Isbell/A.Jones/O.Redding', 1),
#  ('AC/DC', 8),
#  ('Aaron Copland', 1),
#  ('Aaron Goldberg', 1),
#  ('Ace Frehley', 2),
#  ('Acyi Marques/Arlindo Bruz/Braço, Beto Sem/Zeca Pagodinho', 1),
#  ('Acyr Marques/Arlindo Cruz/Franco', 1),
#  ('Adalto Magalha/Lourenco', 1),
#  ('Adam Clayton, Bono, Larry Mullen & The Edge', 11),
#  ('Adam Clayton, Bono, Larry Mullen, The Edge', 11),
#  ('Addie William Jones/Nat Jones', 1),
#  ('Adrian Smith', 5),
#  ('Adrian Smith/Bruce Dickinson', 6),
#  ('Adrian Smith/Bruce Dickinson/Nicko McBrain', 1),
#  ('Adrian Smith/Bruce Dickinson/Steve Harris', 8),
#  ('Adrian Smith/Clive Burr/Steve Harris', 1),
#  ('Adrian Smith/Steve Harris', 5),
#  ('Adrian Smith; Bruce Dickinson', 1),
#  ('Adrian Smith; Bruce Dickinson; Steve Harris', 3),
#  ('Adrian Vanderberg/David Coverdale', 1),
#  ('Adriano Bernandes/Edmar Neves', 1),
#  ('Al Cleveland/Marvin Gaye/Renaldo Benson', 1),
#  ('Al Perkins/Willie Dixon', 1),
#  ('Alanis Morissette & Glenn Ballard', 13),
#  ('Alba Carvalho/Fernando Porto', 1),
#  ('Albert King', 1),
#  ('Alcides Dias Lopes', 1),
#  ('Alcino Corrêa/Monarco', 1),
#  ('Aldir Blanc/Jayme Vignoli', 1),
#  ('Alex North/Hy Zaret', 1),
#  ('Alex Van Halen/David Lee Roth/Edward Van Halen/Michael Anthony', 7),
#  ('Alexandre Brazil/Pedro Luis/Rodrigo Cabelo', 1),
#  ('Alfred Ellis/James Brown', 2),
#  ('Allen Story/George Gordy/Robert Gordy', 1),
#  ('Almir Guineto/Dedé Paraiso/Luverci Ernesto', 1),
#  ('Amos Blakemore/Buddy Guy', 1),
#  ('Andrea Dulbecco', 1),
#  ('Angus Young, Malcolm Young, Brian Johnson', 10),
#  ('Anonymous', 1),
#  ('Anthony Kiedis, Flea, John Frusciante, and Chad Smith', 16),
#  ('Anthony Kiedis/Chad Smith/Flea/John Frusciante', 19),
#  ('Antonio Carlos Jobim', 1),
#  ('Antonio Carlos Jobim/Vinicius de Moraes', 1),
#  ('Antonio Lopes', 1),
#  ('Antonio Vivaldi', 1),
#  ('Apocalyptica', 8),
#  ('Arlindo Cruz/Carlos Sena/Elmo Caetano/Mauricao', 1),
#  ('Arlindo Cruz/Franco/Marquinhos PQD/Negro, Jovelina Pérolo/Zeca Pagodinho', 1),
#  ('Arnaldo Antunes', 1),
#  ('Arnaldo Antunes/Britto, SergioMiklos, Paulo', 1),
#  ('Arnaldo Antunes/Charles Gavin/Marcelo Fromer/Sérgio Britto/Toni Bellotto', 1),
#  ('Arnaldo Anutnes/Branco Mello/Marcelo Fromer/Sergio Brotto/Toni Bellotto', 1),
#  ('Arnaldo Anutnes/Marcelo Fromer/Paulo Miklos', 1),
#  ('Arnaldo Baptista - Rita Lee', 2),
#  ('Arnaldo Baptista - Rita Lee -  Sérgio Dias', 1),
#  ('Arnaldo Baptista - Rita Lee - Arnolpho Lima Filho', 1),
#  ('Arnaldo Baptista - Rita Lee - Sérgio Dias', 1),
#  ('Arnaldo Baptista/Rita Lee/Sérgio Dias', 1),
#  ('Arthur Crudup/Bernard Besman/Bukka White/Doc Pomus/John Bonham/John Lee Hooker/John Paul Jones/Mort Shuman/Robert Plant/Willie Dixon', 1),
#  ('Astor Campbell, Delroy "Chris" Cooper, Donovan Jackson, Dorothy Fields, Earl Chinna Smith, Felix Howard, Gordon Williams, James Moody, Jimmy McHugh, Matt Rowe, Salaam Remi & Stefan Skarbek', 1),
#  ('Astor Piazzolla', 1),
#  ('Audioslave/Chris Cornell', 14),
#  ('Augusto Conceição/Chiclete Com Banana', 1),
#  ('Augusto Garcez/Nelson Cavaquinho', 1),
#  ('Augusto/Craig Negoescu/Rocco Filho/Saara, Ze Carlos Da', 1),
#  ('B. Carter/C. Layton/R. Ellsworth/R. Wynans/T. Shannon', 1),
#  ('B. Cummings/G. Peterson/M.J. Kale/R. Bachman', 1),
#  ('B. Daisley, O. Osbourne & R. Rhoads', 2),
#  ('B. Guy', 1),
#  ('B. de Filippi - F. Migliaci - Versão: Fred Jorge', 1),
#  ('Baden Powell/Vinicius de Moraes', 1),
#  ('Bahiano/Chuck Rio/Diego Blanco/Herbert Vianna', 1),
#  ('Bahiano/Diego Blanco/Herbert Vianna', 1),
#  ('Barrett Strong/Norman Whitfield', 2),
#  ('Barrett Strong/Norman Whitfield/Roger Penzabene', 1),
#  ('Ben E.King/James Bethea', 1),
#  ('Ben Shepherd/Chris Cornell', 1),
#  ('Ben Shepherd/Chris Cornell/Kim Thayil/Matt Cameron', 1),
#  ('Bernardo Vilhena/Bino Farias/Da Gama/Lazão/Toni Garrido', 1),
#  ('Bernardo Vilhena/Bino/Da Gama/Lazao/Toni Garrido', 1),
#  ('Bernardo Vilhena/Da Gama/Lazao', 1),
#  ('Bernardo Vilhena/Da Gama/Lazão', 1),
#  ('Berry Gordy, Jr./Janie Bradford', 1),
#  ('Bert Russell/Phil Medley', 1),
#  ('Beto Gogo/Jessé Pai/Luiz Carlos/Zeca Pagodinho', 1),
#  ('Beto Guedes, Márcio Borges', 1),
#  ('Beto Guedes, Ronaldo Bastos', 1),
#  ('Beto Guedes/Fernando Brant/L Borges', 1),
#  ('Betty Newsome/James Brown', 1),
#  ('Bi Ribeira/Herbert Vianna/João Barone', 1),
#  ('Bi Ribeiro/Herbert Vianna/João Barone', 1),
#  ('Big Bill Broonzy', 1),
#  ('Bill Berry-Peter Buck-Mike Mills-Michael Stipe', 25),
#  ('Bill Berry/Michael Stipe/Mike Mills/Peter Buck', 11),
#  ('Bill Dees/Roy Orbison', 1),
#  ('Bill Gould/Jon Hudson/Mike Bordin/Mike Patton', 1),
#  ('Bill Gould/Jon Hudson/Mike Bordin/Mike Patton/Roddy Bottum', 2),
#  ('Bill Gould/Mike Bordin/Mike Patton', 2),
#  ('Bill Gould/Mike Patton', 2),
#  ('Billie Joe Armstrong -Words Green Day -Music', 20),
#  ('Billie Joe Armstrong, Mike Dirnt, Tré Cool', 2),
#  ('Billie Joe Armstrong/Green Day', 1),
#  ('Billy Cobham', 7),
#  ('Billy Corgan', 31),
#  ('Billy Duffy/Bob Rock/Ian Astbury', 2),
#  ('Billy Duffy/Ian Astbury', 9),
#  ('Billy Duffy/Ian Astbury/Marti Frederiksen/Mick Jones', 1),
#  ('Billy Roberts', 1),
#  ('Billy/Del James/W. Axl Rose/West Arkeen', 1),
#  ('Bino Farias/Da Gama/Henry Lawes/Lazão/Toni Garrido/Winston Foser-Vers', 1),
#  ('Bino Farias/Da Gama/Lazão/Pedro Luis/Toni Garrido', 1),
#  ('Bino Farias/Da Gama/Lazão/Rás Bernardo', 1),
#  ('Bino Farias/Da Gama/Lazão/Toni Garrido', 4),
#  ('Bino Farias/Da Gamma/Lazão/Rás Bernard', 1),
#  ('Bino/Da Gama/Lazao/Ras Bernardo', 1),
#  ('Bino/Da Gama/Ras Bernardo', 2),
#  ('Bino/Da Gama/Toni Garrido', 1),
#  ('Bino/Da Gamma/Lazao/Toni Garrido', 1),
#  ("Bizuca/Clóvis Pê/Gilson Bernini/Marelo D'Aguia", 1),
#  ('Black Sabbath', 1),
#  ('Blackmore, Gillan, Glover, Lord, Paice', 7),
#  ('Blackmore, Glover, Turner', 4),
#  ('Blackmore, Glover, Turner, Lord, Paice', 4),
#  ('Blackmore/Coverdale', 1),
#  ('Blackmore/Coverdale/Lord/Paice', 1),
#  ('Blackmore/Gillan/Glover/Lord/Paice', 1),
#  ('Blaze Bayley/David Murray/Steve Harris', 1),
#  ('Blaze Bayley/Janick Gers', 2),
#  ('Blaze Bayley/Janick Gers/Steve Harris', 4),
#  ('Blaze Bayley/Steve Harris', 1),
#  ('Bo Diddley', 1),
#  ('Bob Cochran/Sharon Sheeley', 1),
#  ('Bob Dylan', 1),
#  ('Bob Rock/James Hetfield/Kirk Hammett/Lars Ulrich', 11),
#  ('Bobby Byrd/James Brown/Ron Lenhoff', 1),
#  ('Bolin/Coverdale', 4),
#  ('Bolin/Coverdale/Paice', 1),
#  ('Bolin/Hughes', 1),
#  ('Bolin/Hughes/Lord', 1),
#  ('Bombom/Ed Motta', 1),
#  ('Bono', 1),
#  ('Bono, The Edge, Adam Clayton, and Larry Mullen', 12),
#  ('Bono/Clayton, Adam/Dylan, Bob/Mullen Jr., Larry/The Edge', 1),
#  ('Bono/Clayton, Adam/Mullen Jr., Larry/The Edge', 12),
#  ('Bossi/David Coverdale/Earl Slick', 2),
#  ('Bourge/Phillips/Shelley', 2),
#  ('Brad Shapiro/George Jackson/Robert Miller/Walter Shaw', 1),
#  ('Branco Mello/Carlos Barmack/Ciro Pessoa/Marcelo Fromer/Toni Belloto', 1),
#  ('Brian Eno, Bono, Adam Clayton, The Edge & Larry Mullen Jnr.', 14),
#  ('Brian Eno/U2', 1),
#  ('Brian Holland/Eddie Holland/Lamont Dozier', 1),
#  ('Brian Holland/Freddie Gorman/Georgia Dobbins/Robert Bateman/William Garrett', 1),
#  ('Brian May', 2),
#  ('Bruce Dickinson', 3),
#  ('Bruce Dickinson/David Murray', 3),
#  ('Bruce Dickinson/David Murray/Steve Harris', 4),
#  ('Bruce Dickinson/Janick Gers', 5),
#  ('Bruce Dickinson/Janick Gers/Steve Harris', 5),
#  ('Bruce Dickinson/Steve Harris', 4),
#  ('Bruce Dickinson; Harris', 1),
#  ('Bruce/Clapton', 3),
#  ('Bryan Adams/Nikki Sixx/Scott Humphrey', 1),
#  ('Buchanan, Wallis', 1),
#  ('Buddy Guy', 3),
#  ('Buzz Cason/Mac Gayden', 1),
#  ('Béla Bartók', 1),
#  ('C. A./C.A./Celso Alvim/Herbert Vianna/Mário Moura/Pedro Luís/Sidon Silva', 1),
#  ('C. Burnett', 1),
#  ('C. Cester', 1),
#  ('C. Cester/C. Muncey', 1),
#  ('C. Cester/C. Muncey/N. Cester', 3),
#  ('C. Cester/N. Cester', 4),
#  ('C. Muncey/N. Cester', 3),
#  ('C.Burton', 1),
#  ('Caetano Veloso', 10),
#  ('Caetano Veloso - Djavan', 1),
#  ('Caetano Veloso - Gilberto Gil', 1),
#  ('Caetano Veloso - Waly Salomão', 1),
#  ('Caetano Veloso e Gilberto Gil', 11),
#  ('Cal Adan/Del Rey, Tension/Edu Casanova', 1),
#  ('Cal Adan/Ferrugem/Julinho Carioca/Tríona Ní Dhomhnaill', 1),
#  ('Cal Adan/Paulo Levi', 1),
#  ('Cale/Clapton', 1),
#  ('Carl Nielsen', 1),
#  ('Carl Orff', 1),
#  ('Carlinhos Brown', 3),
#  ('Carlinhos Brown/Herbert Vianna', 1),
#  ('Carlinhos Santana/Nelson Rufino', 1),
#  ('Carlos Imperial/Edardo Araújo', 1),
#  ('Carlos Imperial/Tim Maia', 1),
#  ('Carlos Santana', 3),
#  ('Carlos Santana & C. Thompson', 1),
#  ('Carlos Santana & Dave Matthews', 1),
#  ('Carlos Santana & KC Porter', 1),
#  ('Carlos Santos/Ciro/Claudio Russo/Zé Luiz', 1),
#  ('Carolyn Franklin and Sonny Saunders', 1),
#  ('Caruso/Cleber/Deo/Osmar', 1),
#  ('Cassiano Costa/Cintia Maviane/J.F./Lucas Costa', 1),
#  ('Cave', 1),
#  ('Charles Bobbitt/James Brown', 2),
#  ('Charles Gavin/Marcelo Fromer/Sérgio Britto', 1),
#  ('Charlie Midnight/Dan Hartman', 1),
#  ('Chester Burnett/Jimmy Page/John Bonham/John Paul Jones/Robert Plant', 1),
#  ('Chet Catallo', 1),
#  ('Chico Amaral/Edgard Scandurra/Samuel Rosa', 1),
#  ('Chico Amaral/Lelo Zanettik', 1),
#  ('Chico Amaral/Samuel Rosa', 6),
#  ('Chico Buarque', 1),
#  ('Chico Science', 23),
#  ('Chico Science/Dengue/Lúcio Maia', 1),
#  ('Chris Cornell', 23),
#  ('Chris Cornell/Kim Thayil', 4),
#  ('Chris Frantz/David Byrne/Jerry Harrison/Tina Weymouth', 1),
#  ('Chris Robinson/Rich Robinson', 18),
#  ('Chuck Berry', 3),
#  ('Cidade Negra', 1),
#  ('Ciro Pressoa/Marcelo Fromer', 1),
#  ('Clapton', 4),
#  ('Clapton/Collins/Pappalardi', 1),
#  ('Clapton/Dylan', 1),
#  ('Clapton/F.eldman/Linn', 1),
#  ('Clapton/Gordon', 1),
#  ('Clapton/Harrison', 1),
#  ('Clapton/J. J. Cale', 1),
#  ('Clapton/Levy', 1),
#  ('Clapton/Robert Johnson Arr: Eric Clapton', 1),
#  ('Clapton/Trad. Arr. Clapton', 1),
#  ('Clarke/Farren/Kilmister/Tayler', 1),
#  ('Clarke/Kilmister/Tayler', 3),
#  ('Clarke/Kilmister/Taylor', 13),
#  ('Claudio Martins/David Lima/Kleber Rodrigues/Livre, Cesare Som', 1),
#  ('Claudio Monteverdi', 1),
#  ('Cliff Burton', 1),
#  ('Collins/Van Zandt', 1),
#  ('Cook/Coverdale', 1),
#  ('Cornell, Commerford, Morello, Wilk', 12),
#  ('Corumbá/José Gumarães/Venancio', 1),
#  ('Coverdale', 5),
#  ('Coverdale/Hughes', 1),
#  ('Coverdale/Hughes/Lord/Paice', 1),
#  ('Coverdale/Lord/Paice', 2),
#  ('Craig Ross/Lenny Kravitz', 1),
#  ('Cub Coda/Michael Lutz', 1),
#  ('Culmer/Exalt', 1),
#  ('D. DeLeo/Kretz/R. DeLeo/Weiland', 1),
#  ('D. DeLeo/Kretz/Weiland', 2),
#  ('D. DeLeo/R. DeLeo/Weiland', 1),
#  ('D.Coverdal/G.Hughes/Glenn Hughes/I.Paice/Ian Paice/J.Lord/John Lord', 1),
#  ('D.Coverdale/G.Hughes/Glenn Hughes/I.Paice/Ian Paice/J.Lord/John Lord/R.Blackmore/Ritchie Blackmore', 3),
#  ('D.Coverdale/G.Hughes/Glenn Hughes/J.Lord/John Lord', 1),
#  ('D.Coverdale/G.Hughes/Glenn Hughes/R.Blackmore/Ritchie Blackmore', 1),
#  ('D.Coverdale/R.Blackmore/Ritchie Blackmore', 3),
#  ('Da Gama/Lazao/Toni Garrido', 1),
#  ('Da Gama/Lazão/Rás Bernardo', 1),
#  ('Da Gama/Toni Garrido', 3),
#  ('Dadinho/Gilbreto Gomes/Gustavo/P.C. Portugal/R. Mocoto', 1),
#  ('Dado Villa-Lobos', 1),
#  ('Dado Villa-Lobos/Ico Ouro-Preto/Marcelo Bonfá', 1),
#  ('Dado Villa-Lobos/Marcelo Bonfá', 8),
#  ('Dale Evans', 1),
#  ('Daniel Lanois', 1),
#  ('Danzig', 2),
#  ('Darius "Take One" Minwalla/Jon Auer/Ken Stringfellow/Matt Harris', 2),
#  ('Dave Abbruzzese & Jeff Ament & Stone Gossard & Mike McCready & Eddie Vedder', 3),
#  ('Dave Abbruzzese/Eddie Vedder/Jeff Ament/Mike McCready/Stone Gossard', 12),
#  ('Dave Brubeck', 1),
#  ('Dave Grohl', 3),
#  ('Dave Grohl, Taylor Hawkins, Nate Mendel, Chris Shiflett', 10),
#  ('Dave Grohl, Taylor Hawkins, Nate Mendel, Chris Shiflett/FOO FIGHTERS', 10),
#  ('Dave Krusen/Stone Gossard', 1),
#  ('Dave Kushner, Duff, Keith Nelson, Matt Sorum, Scott Weiland & Slash', 1),
#  ('Dave Kushner, Duff, Matt Sorum, Scott Weiland & Slash', 12),
#  ('Dave Murray; Steve Harris', 1),
#  ('Dave, Taylor, Nate, Chris', 10),
#  ('David Cook', 1),
#  ('David Corrêa - Paulinho Carvalho - Carlos Sena - Bira do Ponto', 1),
#  ('David Coverdale', 5),
#  ('David Coverdale/Earl Slick', 4),
#  ("David Murray/Paul Di'Anno/Steve Harris", 4),
#  ('David Murray/Steve Harris', 7),
#  ('De Beauport/Jagger/Richards', 1),
#  ('Deacon', 2),
#  ('Deacon, John', 2),
#  ('Deacon, John/May, Brian', 1),
#  ('Deacon/May/Mercury/Taylor', 1),
#  ('Deaffy & R.A. Smith-Diesel', 1),
#  ('Dean Brown, Dennis Chambers & Jim Beard', 1),
#  ('Dean Deleo', 1),
#  ('Deanna Brown/Deidra Jenkins/Yamma Brown', 1),
#  ('Delroy "Chris" Cooper, Donovan Jackson, Earl Chinna Smith, Felix Howard, Gordon Williams, Luke Smith, Paul Watson & Wilburn Squiddley Cole', 1),
#  ('Derrick McKenzie/Jay Kay/Toby Smith', 1),
#  ('Diamond/Shermann', 1),
#  ('Dick Holler', 1),
#  ('Dickinson', 3),
#  ('Dickinson/Smith', 1),
#  ('Dito/Djalma Falcao/Ilha, Almir Da/Márcio André', 1),
#  ('Di´Anno/Harris', 1),
#  ('Djavan', 12),
#  ('Djavan - Gabriel, O Pensador', 1),
#  ('Do Vale, João/Luiz Wanderley', 1),
#  ('Do Vale, Valverde/Gal Oliveira/Luciano Pinto', 1),
#  ('Dolmayan, John/Malakian, Daron/Odadjian, Shavo', 4),
#  ('Dolores Duran', 1),
#  ('Domenil/J. Brito/Joaozinho/Rap, Marcelo Do', 1),
#  ('Dominguinhos/Gilberto Gil', 1),
#  ('Don Van Vliet', 2),
#  ('Donato/Gilberto Gil', 1),
#  ('Douglas/Neves, Vicente Das/Silva, Gilmar L./Toninho Gentil/Wantuir', 1),
#  ('Doyle Bramhall/Stevie Ray Vaughan', 4),
#  ('Dudu Nobre', 1),
#  ('Dudu Nobre/Zeca Pagodinho', 1),
#  ('Duff McKagan', 1),
#  ('Duff McKagan/Slash/W. Axl Rose', 2),
#  ('Dufort/Johnson/McAuliffe/Williams', 1),
#  ('Dylan, Bob', 1),
#  ('E. Schrody/J. Vasquez/L. Dimant', 1),
#  ('E. Schrody/L. Dimant', 6),
#  ('E. Schrody/L. Dimant/L. Muggerud', 1),
#  ('E. Schrody/L. Freese/L. Muggerud', 1),
#  ('E. Schrody/L. Muggerud', 5),
#  ('E. Schrody/L. Muggerud/R. Medrano', 1),
#  ('E. Schrody/R. Medrano', 2),
#  ('E. Shrody', 1),
#  ('E.Weiss', 2),
#  ('Eale-Eye Cherry, M. Simpson, J. King & M. Nishita', 1),
#  ('Eddie Casillas/Roy Z', 1),
#  ('Eddie Cochran/Jerry Capehart', 1),
#  ('Eddie Vedder', 12),
#  ('Eddie Vedder & Mike McCready', 3),
#  ('Eddie Vedder & Stone Gossard', 1),
#  ('Eddie Vedder/Jeff Ament/Matt Cameron/Mike McCready/Stone Gossard', 1),
#  ('Edvard Grieg', 1),
#  ('Edward Elgar', 2),
#  ('Edward Van Halen, Alex Van Halen, David Lee Roth', 2),
#  ('Edward Van Halen, Alex Van Halen, David Lee Roth, Michael Anthony', 6),
#  ('Edward Van Halen, Alex Van Halen, Michael Anthony and David Lee Roth', 9),
#  ('Edward Van Halen, Alex Van Halen, Michael Anthony,/Edward Van Halen, Alex Van Halen, Michael Anthony, David Lee Roth', 2),
#  ('Edward Van Halen, Alex Van Halen, Michael Anthony,/Edward Van Halen, Alex Van Halen, Michael Anthony, Sammy Hagar', 4),
#  ('Emerson Villani', 1),
#  ('Enotris Johnson/Little Richard/Robert "Bumps" Blackwell', 1),
#  ('Erasmo Carlos/Roberto Carlos', 1),
#  ('Eric Clapton', 2),
#  ('Eric Clapton, Jim Gordon', 1),
#  ('Eric Clapton, Robert Cray', 1),
#  ('Eric Clapton, Will Jennings', 1),
#  ('Erik Satie', 1),
#  ('Eugene McDaniel', 1),
#  ('Eurreal Montgomery', 1),
#  ('F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. Dirkscneider & W. Hoffman', 1),
#  ('F. Baltes, S. Kaufman, U. Dirkscneider & W. Hoffman', 1),
#  ('F. Olivera', 1),
#  ('Faith No More', 10),
#  ('Faithfull/Jagger/Richards', 1),
#  ('Fausto Fawcett/Samuel Rosa', 1),
#  ('Fausto Nilo - Armandinho', 1),
#  ('Fausto Nilo/Moraes Moreira/Pepeu Gomes', 1),
#  ('Fayyaz Virgi/Richard Bull', 1),
#  ('Fito Paez/Herbert Vianna', 1),
#  ('Flavio Bororo/Paulo Apparicio/Wagner Alves/Zeca Sereno', 1),
#  ('Folclore', 1),
#  ('Foo Fighters', 11),
#  ('Frank Zappa', 7),
#  ('Franz Joseph Haydn', 1),
#  ('Franz Schubert', 2),
#  ('Fred Wesley/James Brown', 1),
#  ('Fred Wesley/James Brown/Joseph Mims', 1),
#  ('Freddie Mercury', 1),
#  ('Freddie Mercury & John Deacon', 1),
#  ('Freddy James, Jimmy hogarth & Larry Stock', 1),
#  ('Frédéric Chopin', 1),
#  ('Full Force/James Brown', 1),
#  ('Fábio Nolasco/Gal Sales/Ivan Brasil', 1),
#  ('G Harvey/R Hope-Taylor', 1),
#  ('G M Sumner', 14),
#  ('Gabriel Fauré', 1),
#  ('Galley', 1),
#  ('Garay, Ricardo Engels/Luca Predabom/Ludwig, Carlos Henrique/Maurício Vieira', 1),
#  ('Geddy Lee And Alex Lifeson/Geddy Lee And Neil Peart/Rush', 14),
#  ('Gelder, Nick van', 1),
#  ('Gene Simmons', 7),
#  ('Gene Simmons, S. Coronel', 2),
#  ('Gene Simmons, Stephen Coronel', 1),
#  ('Genival Cassiano', 1),
#  ('Genival Cassiano/Silvio Rochael', 1),
#  ('George Duke', 1),
#  ('George Frideric Handel', 3),
#  ('Georges Bizet', 1),
#  ('Gerry DeVeaux/Terry Britten', 1),
#  ('Giacomo Puccini', 2),
#  ('Gil Evans', 2),
#  ('Gilberto Gil', 23),
#  ('Gilberto Gil - Caetano Veloso', 1),
#  ('Gillan/Glover/Lord/Nix - Blackmore/Paice', 1),
#  ('Gillan/Glover/Lord/Paice', 1),
#  ('Gilmour, Mason, Wright, Waters', 1),
#  ('Gilmour, Waters', 1),
#  ('Gilson Mendonça/Michel', 1),
#  ('Giovanni Pierluigi da Palestrina', 1),
#  ('Giuseppe Verdi', 1),
#  ('Gonzaga Jr', 1),
#  ('Gonzaga Jr.', 3),
#  ('Gonzaga Jr/Gonzaguinha', 1),
#  ('Gonzaguinha', 1),
#  ('Graham Harvey', 1),
#  ('Grazielle/Roque Ferreira', 1),
#  ('Green Day', 7),
#  ('Greg Macainsh', 1),
#  ('Gregorio Allegri', 1),
#  ('Guga/Marquinho Lessa/Tuninho Professor', 1),
#  ('Guio De Morais E Seus "Parentes"/Luiz Gonzaga', 1),
#  ('Gule/Jorge 101/Lequinho/Luiz Piao', 1),
#  ('Gustav Holst', 1),
#  ('Gustav Mahler', 1),
#  ('H. Spina, J. Elliott', 2),
#  ('Habib Koité', 2),
#  ('Harris', 7),
#  ('Harris/Di Anno', 1),
#  ('Harris/Paul Di´Anno', 2),
#  ('Harris/Tatler', 4),
#  ('Harry Lawes/Winston Foster-Vers', 1),
#  ('Hawkins-Lewis-Broadwater', 1),
#  ('Heath/Robinson', 1),
#  ('Hector Berlioz', 1),
#  ('Hendrix, Jimi', 1),
#  ('Henry Hirsch/Lenny Kravitz', 1),
#  ('Henry Kirssch/Lenny Kravitz/S. Pasch A. Krizan', 1),
#  ('Henry Purcell', 2),
#  ('Henryk Górecki', 1),
#  ('Herbert Vianna', 19),
#  ('Herbert Vianna/Paulo Sérgio Valle', 1),
#  ('Herbert Vianna/Tet Tillett', 1),
#  ('Herbert Vianna/Tetê Tillet', 1),
#  ('Hetfield, Ulrich', 6),
#  ('Hetfield, Ulrich, Hammett', 6),
#  ('Hetfield, Ulrich, Newsted', 1),
#  ('Holocaust', 1),
#  ('Humberto Teixeira/Luiz Gonzaga', 4),
#  ('Hyldon', 1),
#  ('I. Toure, S. Tidiane Toure, Carlos Santana & K. Perazzo', 1),
#  ('Ian Gillan, Roger Glover, Jon Lord, Steve Morse, Ian Paice', 12),
#  ('Ian Gillan/Ian Paice/Jon Lord/Ritchie Blckmore/Roger Glover', 7),
#  ('Ian Stewart/John Bonham/John Paul Jones/Mrs. Valens/Robert Plant', 1),
#  ('Igor Stravinsky', 1),
#  ('Ira Gershwin, Kurt Weill', 1),
#  ('Isham Jones & Marty Symes', 1),
#  ('Ivan Kral/Patti Smith', 1),
#  ('Ivy Hunter/Stevie Wonder', 1),
#  ('Ivy Hunter/William "Mickey" Stevenson', 1),
#  ('Ivy Jo Hunter/Marvin Gaye/William Stevenson', 1),
#  ("Izzy Stradlin'", 1),
#  ("Izzy Stradlin'/W. Axl Rose", 3),
#  ('J B Lenoir/Willie Dixon', 2),
#  ('J. B. Lenoir/Willie Dixon', 1),
#  ('J. C. Fogerty', 17),
#  ('J. Carisi', 2),
#  ('J. Kay/Jay Kay', 2),
#  ('J. Purdell, M. Inez, O. Osbourne, R. Castillo & Z. Wylde', 1),
#  ('J. Satriani', 4),
#  ('J.C. Fogerty', 20),
#  ('J.Hetfield/L.Ulrich', 2),
#  ('J.J. Johnson', 1),
#  ('J.J. Johnson/R. Troup, L. Worth', 1),
#  ('J.r.Bertami/Parana', 1),
#  ('Jack Yellen/Milton Ager', 1),
#  ('Jagger/Richards', 35),
#  ('Jagger/Richards/Oldham', 1),
#  ('James Brown', 3),
#  ('James Brown & Bobby Byrd', 1),
#  ('James Brown/Johnny Terry', 1),
#  ('James Brown/Tim Maia', 1),
#  ('James Hetfield', 1),
#  ('James Hetfield & Lars Ulrich', 1),
#  ('James Hetfield and Lars Ulrich', 2),
#  ('James Hetfield, Lars Ulrich', 11),
#  ('James Hetfield, Lars Ulrich & Jason Newsted', 1),
#  ('James Hetfield, Lars Ulrich & Kirk Hammett', 2),
#  ('James Hetfield, Lars Ulrich and Cliff Burton', 1),
#  ('James Hetfield, Lars Ulrich and Jason Newsted', 1),
#  ('James Hetfield, Lars Ulrich and Kirk Hammett', 6),
#  ('James Hetfield, Lars Ulrich, Dave Mustaine', 4),
#  ('James Hetfield, Lars Ulrich, Kirk Hammett', 7),
#  ('James Iha', 1),
#  ('Janick Gers/Steve Harris', 9),
#  ('Jauperi/Zeu Góes', 1),
#  ('Jay Beckenstein', 3),
#  ('Jay Hawkins', 1),
#  ('Jay Kay', 4),
#  ('Jay Kay/Kay, Jay', 2),
#  ('Jay Kay/Toby Smith', 5),
#  ('Jean Paul Maunick', 2),
#  ('Jean Sibelius', 1),
#  ('Jeff Ament', 7),
#  ('Jeff Ament & Eddie Vedder', 1),
#  ('Jeff Ament & Stone Gossard & Jack Irons & Mike McCready & Eddie Vedder', 1),
#  ('Jeff Ament/Mike McCready/Stone Gossard', 1),
#  ('Jeff Ament/Stone Gossard', 3),
#  ('Jeremy Wall', 4),
#  ('Jerry Cantrell', 6),
#  ('Jerry Cantrell, Layne Staley', 4),
#  ('Jerry Cantrell, Michael Starr, Layne Staley', 1),
#  ('Jerry Cantrell, Michael Starr, Sean Kinney', 1),
#  ('Jerry Lynn Williams', 1),
#  ('Jerry Ragavoy', 1),
#  ('Jesse Ed Davis III/Taj Mahal', 1),
#  ('Jesse Fuller', 1),
#  ('Jim Beard', 2),
#  ('Jim Beard & Jon Herington', 1),
#  ('Jimi Hendrix', 16),
#  ('Jimmy Cox', 1),
#  ('Jimmy Forrest/Lewis C. Simpkins/Oscar Washington', 1),
#  ('Jimmy Page', 6),
#  ('Jimmy Page & Robert Plant', 1),
#  ('Jimmy Page, Robert Plant', 15),
#  ('Jimmy Page, Robert Plant & John Paul Jones', 3),
#  ('Jimmy Page, Robert Plant, Charlie Jones, Michael Lee', 12),
#  ('Jimmy Page, Robert Plant, John Bonham', 1),
#  ('Jimmy Page, Robert Plant, John Bonham, John Paul Jones', 1),
#  ('Jimmy Page, Robert Plant, John Paul Jones', 5),
#  ('Jimmy Page, Robert Plant, John Paul Jones, John Bonham', 4),
#  ('Jimmy Page, Robert Plant, John Paul Jones, John Bonham, Memphis Minnie', 1),
#  ('Jimmy Page/Jimmy Page & Robert Plant/Robert Plant', 4),
#  ('Jimmy Page/John Bonham/John Estes/John Paul Jones/Robert Plant', 1),
#  ('Jimmy Page/John Bonham/John Paul Jones', 6),
#  ('Jimmy Page/John Bonham/John Paul Jones/Robert Plant/Willie Dixon', 1),
#  ('Jimmy Page/John Paul Jones', 1),
#  ('Jimmy Page/Led Zeppelin', 1),
#  ('Jimmy Page/Robert Johnson/Robert Plant', 1),
#  ('Jimmy Page/Robert Plant', 12),
#  ('Jimmy and Vella Cameron', 1),
#  ('Joe Strummer/Mick Jones', 9),
#  ('Johann Pachelbel', 1),
#  ('Johann Sebastian Bach', 7),
#  ('Johann Strauss II', 1),
#  ('John Adams', 1),
#  ('John Bonham', 2),
#  ('John Bonham, John Paul Jones, Jimmy Page', 1),
#  ('John Bonham/John Paul Jones', 6),
#  ('John Bonham/John Paul Jones/Robert Plant', 2),
#  ('John Bonham/John Paul Jones/Robert Plant/Willie Dixon', 1),
#  ('John Brim', 1),
#  ('John Deacon', 1),
#  ('John Dowland', 1),
#  ('John Entwistle', 1),
#  ('John Entwistle/Pete Townshend', 5),
#  ('John Lennon, Paul McCartney', 1),
#  ('John Paul Jones', 2),
#  ('John Paul Jones & Robert Plant', 1),
#  ('John Paul Jones, Jimmy Page & Robert Plant', 1),
#  ('John Paul Jones/Robert Plant', 6),
#  ('John Scofield', 1),
#  ('John Scofield, Robert Aries, Milton Chambers and Gary Grainger', 1),
#  ('John and William Valentine', 1),
#  ('Jon Herington', 1),
#  ('Jon Hudson/Mike Bordin/Mike Patton', 1),
#  ('Jon Hudson/Mike Patton', 1),
#  ('Jones/Sirotto/Smith', 1),
#  ('Jorge Aragão/Zeca Pagodinho', 1),
#  ('Jorge Ben', 2),
#  ('Jorge Cardoso/Pierre Onasis', 1),
#  ('Jorge Vercilo/Jota Maranhao', 1),
#  ('João Suplicy', 14),
#  ('Julian Crampton', 1),
#  ('K.Hammett', 5),
#  ('KC Porter & JB Eckl', 1),
#  ('Karol Szymanowski', 1),
#  ('Karsh Kale', 1),
#  ('Karsh Kale/Vishal Vaid', 1),
#  ('Keith Richards/Mick Jagger', 1),
#  ('Kelly, Mosley, Rothery, Trewaves', 10),
#  ('Kenny Gamble and Leon Huff', 1),
#  ('Kevin Robinson', 1),
#  ('Kevin Robinson/Richard Bull', 1),
#  ('Killing Joke', 1),
#  ('Kretz/R. DeLeo/Weiland', 1),
#  ('Kurt Cobain', 26),
#  ('Kurt Weill', 1),
#  ('L. Delibes', 1),
#  ('L. Hill', 1),
#  ('L. Kerslake, O. Osbourne, R. Daisley & R. Rhoads', 1),
#  ('L. Kilmister, O. Osbourne & Z. Wylde', 1),
#  ('L. Muggerud', 2),
#  ('Larry Williams', 2),
#  ('Lennon, John/McCartney, Paul', 1),
#  ('Lenny Kravitz', 9),
#  ('Lenny Kravitz/Slash', 1),
#  ('Leão, Rodrigo F./Lô Borges/Samuel Rosa', 1),
#  ('Leão, Rodrigo F./Samuel Rosa', 1),
#  ('Little Richard', 1),
#  ('Lowman Pauling', 1),
#  ('Luca Gusella', 1),
#  ('Luciana Souza', 1),
#  ('Lucina/Luli', 1),
#  ('Ludwig van Beethoven', 5),
#  ('Luiz Carlos/Oberdan', 1),
#  ('Luiz Gonzaga/Zé Dantas', 1),
#  ('Luiz Melodia/Ricardo Augusto', 1),
#  ('Luiz Wanderley/Paulo Levi', 1),
#  ('Luke Smith', 1),
#  ('Lulu Santos', 2),
#  ('Lô Borges, Fernando Brant', 1),
#  ('Lô Borges, Márcio Borges, Fernando Brant', 1),
#  ('M. Itaal Shur & Rob Thomas', 1),
#  ('M.Babatunde Olantunji', 1),
#  ('Mabins, Macie/Magee, Sterling/Robinson, Bobby', 1),
#  ('Macelo Yuka/O Rappa', 1),
#  ('Manuca/Raimundinho DoAcordion/Targino Godim', 1),
#  ('Marc-Antoine Charpentier', 1),
#  ('Marco Tulio Lara/Rogerio Flausino', 1),
#  ('Marcos Valle', 1),
#  ('Marisa Monte/Nando Reis', 2),
#  ('Marisa Monte/poema de Octavio Paz/versão: Haroldo de Campos', 1),
#  ('Mark Ronson', 1),
#  ('Marley', 1),
#  ('Marsden', 1),
#  ('Marsden/Moody', 1),
#  ('Marvin Gaye', 4),
#  ('Mason, Waters, Wright, Gilmour', 1),
#  ('Mason/Waters, Gilmour, Wright', 1),
#  ('Matt Cameron', 3),
#  ('Matt Cameron & Mike McCready', 1),
#  ('Matt Rowe & Stefan Skarbek', 1),
#  ('Mauro Diniz/Ratino Sigem', 1),
#  ('Maxton Gig Beesley Jnr.', 1),
#  ('May', 4),
#  ('May, Brian', 4),
#  ('McKinley Morgenfield (Muddy Waters)', 1),
#  ('Mercury', 3),
#  ('Mercury, Freddie', 10),
#  ('Metallica', 8),
#  ('Michael Jackson', 1),
#  ('Mick Hucknall', 7),
#  ('Mick Hucknall and Fritz McIntyre', 2),
#  ('Mick Hucknall and Lamont Dozier', 1),
#  ('Mick Hucknall and Neil Moss', 1),
#  ('Mick Jagger, Keith Richard', 1),
#  ('Mick Jones/Traditional arr. Joe Strummer', 1),
#  ('Mick Mars/Nikki Sixx', 3),
#  ('Mick Mars/Nikki Sixx/Tommy Lee', 2),
#  ('Mick Mars/Nikki Sixx/Tommy Lee/Vince Neil', 3),
#  ('Mike Bordin, Billy Gould, Mike Patton', 10),
#  ('Mike Bordin, Billy Gould, Mike Patton, Trey Spruance', 5),
#  ('Mike Dint, Billie Joe, Tré Cool', 2),
#  ('Mike Dirnt -Words Green Day -Music', 1),
#  ('Mike Dirnt/Tré Cool', 1),
#  ('Mike McCready', 1),
#  ('Mike McCready & Stone Gossard', 1),
#  ('Mike Patton', 3),
#  ('Miles Davis', 23),
#  ('Miles Davis, Gil Evans', 1),
#  ('Milton Nascimento', 1),
#  ('Milton Nascimento, Caetano Veloso', 2),
#  ('Milton Nascimento, Fernando Brant', 9),
#  ('Milton Nascimento, Márcio Borges', 1),
#  ('Milton Nascimento, Ronaldo Bastos', 3),
#  ('Molaney/Morris/Roberts/Wainwright', 2),
#  ('Moody', 1),
#  ('Morais', 1),
#  ('Murilão', 1),
#  ('Murray  Dave', 1),
#  ('Mutantes', 1),
#  ('Mônica Marianno', 12),
#  ('N. Cester', 1),
#  ('Nando Reis', 3),
#  ('Nando Reis/Samuel Rosa', 1),
#  ('Nanker Phelge', 1),
#  ('Ned Fairchild', 1),
#  ('Nei Lopes/Wilson Moreira', 1),
#  ('Neil Young', 1),
#  ('Nelson Angelo', 1),
#  ('Niccolò Paganini', 1),
#  ('Nickolas Ashford & Valerie Simpson', 1),
#  ('Nikki Sixx', 5),
#  ('Nikki Sixx/Tommy Lee/Vince Neil', 2),
#  ('Nikolai Rimsky-Korsakov', 1),
#  ('Nirvana', 3),
#  ('O. Osbourne', 1),
#  ('O. Osbourne, R. Daisley, R. Rhoads', 9),
#  ('O. Osbourne, R. Daisley, R. Rhoads, L. Kerslake', 1),
#  ('Orestes Barbosa-Sílvio Caldas', 1),
#  ('Os Mutantes - Arnolpho Lima Filho', 1),
#  ('Page, Jones', 1),
#  ('Patrick Claher/Richard Bull', 1),
#  ("Paul Di'Anno/Steve Harris", 5),
#  ("Paul O'duffy", 1),
#  ('Paul Stanley', 5),
#  ('Paul Stanley, Ace Frehley', 2),
#  ('Paul Stanley, B. Ezrin', 1),
#  ('Paul Stanley, B. Ezrin, K. Fowley', 1),
#  ('Paul Stanley, Bob Ezrin, Kim Fowley', 1),
#  ('Paul Stanley, Gene Simmons', 3),
#  ('Paul Stanley, Gene Simmons, B. Ezrin', 1),
#  ('Paul Stanley, Gene Simmons, Bob Ezrin, Lewis Reed', 1),
#  ('Paul Stanley, Gene Simmons, Rus Ballard, Bob Ezrin', 1),
#  ('Paul Stanley, Vincent Cusano', 1),
#  ('Paul Stanley, Vincent Poncia', 2),
#  ('Paul Stanley, Vincent Poncia, Desmond Child', 1),
#  ('Paulinho Rezende/Toninho Geraes', 1),
#  ('Paulo Levi/W. Rangel', 1),
#  ('Pearl Jam', 2),
#  ('Pearl Jam & Eddie Vedder', 1),
#  ('Peninha', 1),
#  ('Pete Townshend', 13),
#  ('Pete Townshend, Roger Daltrey', 1),
#  ('Peter Criss, Stan Penridge, Bob Ezrin', 1),
#  ('Peter Ilyich Tchaikovsky', 1),
#  ('Philip Glass', 1),
#  ('Pietro Antonio Locatelli', 1),
#  ('Pietro Mascagni', 1),
#  ('Queen', 9),
#  ('Queen & David Bowie', 1),
#  ('R. Carless', 1),
#  ('R. DeLeo/Weiland', 6),
#  ('R. Rhoads', 1),
#  ('R. Taha, Carlos Santana & T. Lindsay', 1),
#  ('R. Troup, L. Worth', 1),
#  ('R.E.M.', 16),
#  ('Ralph Vaughan Williams', 1),
#  ('Ratinho/Zeca Pagodinho', 1),
#  ('Ray Davies', 2),
#  ('Red Hot Chili Peppers', 12),
#  ('Renato Russo', 20),
#  ('Renato Russo - Marcelo Bonfá', 1),
#  ('Renato Russo - Marisa Monte', 1),
#  ('Richard Bull', 2),
#  ('Richard Poindexter & Robert Poindexter', 1),
#  ('Richard Wagner', 1),
#  ('Richie Blackmore, Ian Gillian, Roger Glover', 2),
#  ('Richie Blackmore, Ian Gillian, Roger Glover, Ian Paice', 1),
#  ('Richie Blackmore, Ian Gillian, Roger Glover, Jon Lord', 2),
#  ('Richie Blackmore, Ian Gillian, Roger Glover, Jon Lord, Ian Paice', 5),
#  ('Rick Strauss', 1),
#  ('Rita Lee - Arnaldo Baptista - Sérgio Baptista', 1),
#  ('Ritchie Blackmore, Ian Gillan, Roger Glover, Jon Lord, Ian Paice', 7),
#  ('Robby Krieger, Ray Manzarek, John Densmore, Jim Morrison', 9),
#  ('Robert Geddins/Ron Badger/Sheldon Feinberg', 1),
#  ('Robert Johnson', 3),
#  ('Robert Plant', 13),
#  ('Robert Plant & John Paul Jones', 1),
#  ('Robert Rogers/Warren "Pete" Moore/William "Mickey" Stevenson', 1),
#  ('Rodolfo', 10),
#  ('Roger Taylor', 2),
#  ('Roy Z', 8),
#  ('S. Penridge, Bob Ezrin, Peter Criss', 1),
#  ('Salaam Remi', 2),
#  ('Samuel Barber', 1),
#  ('Samuel Rosa', 11),
#  ('Santana', 1),
#  ('Seger', 1),
#  ('Sergei Prokofiev', 1),
#  ('Slash/W. Axl Rose', 1),
#  ('Smith, Toby', 6),
#  ('Smith/Dickinson', 3),
#  ('Smokey Robinson/Warren "Pete" Moore', 1),
#  ('Sonny Boy Williamson [I]', 1),
#  ('Sonny Curtis', 1),
#  ('Soundgarden', 1),
#  ('South', 1),
#  ('Steve Harris', 80),
#  ('Steven Tyler, Desmond Child', 1),
#  ('Steven Tyler, Jim Vallance', 2),
#  ('Steven Tyler, Joe Perry', 1),
#  ('Steven Tyler, Joe Perry, Desmond Child', 3),
#  ('Steven Tyler, Joe Perry, Jack Blades, Tommy Shaw', 1),
#  ('Steven Tyler, Joe Perry, Jim Vallance', 1),
#  ('Steven Tyler, Joe Perry, Jim Vallance, Holly Knight', 1),
#  ('Steven Tyler, Joe Perry, Mark Hudson', 1),
#  ('Steven Tyler, Joe Perry, Taylor Rhodes', 2),
#  ('Steven Tyler, Richie Supa', 1),
#  ('Steven Tyler, Tom Hamilton', 1),
#  ('Stevie Nicks', 1),
#  ('Stevie Ray Vaughan', 2),
#  ('Stone Gossard', 8),
#  ('Stone Gossard & Eddie Vedder', 2),
#  ('Stone Gossard & Eddie Vedder & Jeff Ament & Mike McCready', 1),
#  ('Stuard Zender/Toby Smith', 1),
#  ('Stuart Zender', 1),
#  ('Sully Erna', 10),
#  ('Sully Erna; Tony Rombola', 2),
#  ('Sweet Savage', 1),
#  ('Sykes', 4),
#  ('Sylvester Stewart', 1),
#  ('Sérgio Britto', 2),
#  ('Sérgio Britto/Toni Bellotto', 1),
#  ('Tankian, Serj', 7),
#  ('Taylor', 2),
#  ('Ted Wright', 1),
#  ('Terry Bozzio, Steve Stevens, Tony Levin', 7),
#  ('The Clash', 7),
#  ('The Tea Party', 24),
#  ('Thomas Tallis', 1),
#  ('Tim Maia', 9),
#  ('Titãs', 22),
#  ('Toby Smith', 7),
#  ('Toby Smith/Wallis Buchanan', 1),
#  ('Tom Jobim - Newton Mendoça', 1),
#  ('Toni Bellotto', 1),
#  ('Toninho Horta', 1),
#  ('Tony Iommi, Bill Ward, Geezer Butler, Ozzy Osbourne', 11),
#  ('Tradicional', 1),
#  ('Traditional', 4),
#  ('Turner, Held, Greenwood', 1),
#  ('U2', 44),
#  ("U2 & Daragh O'Toole", 1),
#  ('U2 & Van Dyke Parks', 1),
#  ('U2; Bono', 8),
#  ('U2; Bono & Edge, The', 1),
#  ('U2; Edge, The', 1),
#  ('Ulrich', 7),
#  ('Van Halen', 15),
#  ('Vandenberg', 4),
#  ('Vários', 17),
#  ('W. Axl Rose', 4),
#  ('W. Jean, J. Duplessis, Carlos Santana, K. Perazzo & R. Rekow', 1),
#  ('W.Correa', 1),
#  ('Wagner Tiso, Milton Nascimento', 1),
#  ('Waters', 3),
#  ('Waters, Wright', 1),
#  ('Weill-Brecht', 1),
#  ('Whitfield-Strong', 1),
#  ('William "Mickey" Stevenson', 1),
#  ('William Byrd', 1),
#  ('Willie Dixon', 8),
#  ('Willie Dixon, C. Burnett', 1),
#  ('Wolfgang Amadeus Mozart', 5),
#  ('Wright, Waters', 1),
#  ('alan bergman/marilyn bergman/peggy lipton jones/quincy jones', 1),
#  ('antonio carlos jobim/norman gimbel/vinicius de moraes', 1),
#  ('bart howard', 1),
#  ('bert brecht/kurt weill/marc blitzstein', 1),
#  ('berthold kaempfert/charles singleton/eddie snyder', 1),
#  ('carl sigman/gilbert becaud/pierre leroyer', 1),
#  ('carolyn leigh/cy coleman', 1),
#  ('carson c. parks', 1),
#  ('claude françois/gilles thibault/jacques revaux/paul anka', 1),
#  ('cole porter', 2),
#  ('dean kay thompson/kelly gordon', 1),
#  ('ervin drake', 1),
#  ('fred ebb/john kander', 1),
#  ('george gershwin/ira gershwin', 1),
#  ('hans bradtke/heinz meier/johnny mercer', 1),
#  ('henry mancini/johnny mercer', 1),
#  ('ian paice/jon lord', 1),
#  ('jim croce', 1),
#  ('jimmy van heusen/sammy cahn', 3),
#  ('jon lord/roger glover', 2),
#  ('lorenz hart/richard rodgers', 1),
#  ('orlando murden/ronald miller', 1),
#  ('rod mckuen', 1),
#  ('roger glover', 7)]

# %% [markdown]
# **Tips:** Dealing with Null values - Use the [COALESCE function](https://www.postgresqltutorial.com/postgresql-tutorial/postgresql-coalesce/) to return an alternative non-null value. For example
# `coalesce(composer, 'Unknown')`

# %%
# %%sql
# -- run this cell to try it out!
# SELECT trackid, name, composer, coalesce(composer, 'Unknown')
# FROM tracks
# WHERE composer IS null;

# %% [markdown]
# #### Ex. 2
# How many songs did each composer write in each genre? Show missing composers as "Unknown"
#
# _(hint: group by both composer and genre)_

# %%
# %%sql
# -- Write Your Query here
# SELECT COALESCE(composer, 'Unknown'), genreid, COUNT(name) FROM tracks GROUP BY COALESCE(composer, 'Unknown'), genreid;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('A. F. Iommi, W. Ward, T. Butler, J. Osbourne', 3, 3),
#  ('A. Jamal', 2, 1),
#  ('A.Bouchard/J.Bouchard/S.Pearlman', 3, 1),
#  ('A.Isbell/A.Jones/O.Redding', 6, 1),
#  ('AC/DC', 1, 8),
#  ('Aaron Copland', 24, 1),
#  ('Aaron Goldberg', 2, 1),
#  ('Ace Frehley', 1, 2),
#  ('Acyi Marques/Arlindo Bruz/Braço, Beto Sem/Zeca Pagodinho', 7, 1),
#  ('Acyr Marques/Arlindo Cruz/Franco', 7, 1),
#  ('Adalto Magalha/Lourenco', 7, 1),
#  ('Adam Clayton, Bono, Larry Mullen & The Edge', 1, 11),
#  ('Adam Clayton, Bono, Larry Mullen, The Edge', 1, 11),
#  ('Addie William Jones/Nat Jones', 14, 1),
#  ('Adrian Smith', 3, 5),
#  ('Adrian Smith/Bruce Dickinson', 1, 1),
#  ('Adrian Smith/Bruce Dickinson', 3, 5),
#  ('Adrian Smith/Bruce Dickinson/Nicko McBrain', 13, 1),
#  ('Adrian Smith/Bruce Dickinson/Steve Harris', 1, 1),
#  ('Adrian Smith/Bruce Dickinson/Steve Harris', 3, 5),
#  ('Adrian Smith/Bruce Dickinson/Steve Harris', 13, 2),
#  ('Adrian Smith/Clive Burr/Steve Harris', 3, 1),
#  ('Adrian Smith/Steve Harris', 1, 1),
#  ('Adrian Smith/Steve Harris', 3, 2),
#  ('Adrian Smith/Steve Harris', 13, 2),
#  ('Adrian Smith; Bruce Dickinson', 3, 1),
#  ('Adrian Smith; Bruce Dickinson; Steve Harris', 3, 3),
#  ('Adrian Vanderberg/David Coverdale', 1, 1),
#  ('Adriano Bernandes/Edmar Neves', 9, 1),
#  ('Al Cleveland/Marvin Gaye/Renaldo Benson', 14, 1),
#  ('Al Perkins/Willie Dixon', 6, 1),
#  ('Alanis Morissette & Glenn Ballard', 1, 13),
#  ('Alba Carvalho/Fernando Porto', 7, 1),
#  ('Albert King', 1, 1),
#  ('Alcides Dias Lopes', 7, 1),
#  ('Alcino Corrêa/Monarco', 7, 1),
#  ('Aldir Blanc/Jayme Vignoli', 7, 1),
#  ('Alex North/Hy Zaret', 1, 1),
#  ('Alex Van Halen/David Lee Roth/Edward Van Halen/Michael Anthony', 1, 7),
#  ('Alexandre Brazil/Pedro Luis/Rodrigo Cabelo', 7, 1),
#  ('Alfred Ellis/James Brown', 14, 2),
#  ('Allen Story/George Gordy/Robert Gordy', 14, 1),
#  ('Almir Guineto/Dedé Paraiso/Luverci Ernesto', 7, 1),
#  ('Amos Blakemore/Buddy Guy', 6, 1),
#  ('Andrea Dulbecco', 2, 1),
#  ('Angus Young, Malcolm Young, Brian Johnson', 1, 10),
#  ('Anonymous', 24, 1),
#  ('Anthony Kiedis, Flea, John Frusciante, and Chad Smith', 1, 16),
#  ('Anthony Kiedis/Chad Smith/Flea/John Frusciante', 1, 3),
#  ('Anthony Kiedis/Chad Smith/Flea/John Frusciante', 4, 16),
#  ('Antonio Carlos Jobim', 7, 1),
#  ('Antonio Carlos Jobim/Vinicius de Moraes', 7, 1),
#  ('Antonio Lopes', 4, 1),
#  ('Antonio Vivaldi', 24, 1),
#  ('Apocalyptica', 3, 8),
#  ('Arlindo Cruz/Carlos Sena/Elmo Caetano/Mauricao', 7, 1),
#  ('Arlindo Cruz/Franco/Marquinhos PQD/Negro, Jovelina Pérolo/Zeca Pagodinho', 7, 1),
#  ('Arnaldo Antunes', 4, 1),
#  ('Arnaldo Antunes/Britto, SergioMiklos, Paulo', 4, 1),
#  ('Arnaldo Antunes/Charles Gavin/Marcelo Fromer/Sérgio Britto/Toni Bellotto', 4, 1),
#  ('Arnaldo Anutnes/Branco Mello/Marcelo Fromer/Sergio Brotto/Toni Bellotto', 4, 1),
#  ('Arnaldo Anutnes/Marcelo Fromer/Paulo Miklos', 4, 1),
#  ('Arnaldo Baptista - Rita Lee', 4, 2),
#  ('Arnaldo Baptista - Rita Lee -  Sérgio Dias', 4, 1),
#  ('Arnaldo Baptista - Rita Lee - Arnolpho Lima Filho', 4, 1),
#  ('Arnaldo Baptista - Rita Lee - Sérgio Dias', 4, 1),
#  ('Arnaldo Baptista/Rita Lee/Sérgio Dias', 4, 1),
#  ('Arthur Crudup/Bernard Besman/Bukka White/Doc Pomus/John Bonham/John Lee Hooker/John Paul Jones/Mort Shuman/Robert Plant/Willie Dixon', 1, 1),
#  ('Astor Campbell, Delroy "Chris" Cooper, Donovan Jackson, Dorothy Fields, Earl Chinna Smith, Felix Howard, Gordon Williams, James Moody, Jimmy McHugh, Matt Rowe, Salaam Remi & Stefan Skarbek', 9, 1),
#  ('Astor Piazzolla', 24, 1),
#  ('Audioslave/Chris Cornell', 1, 14),
#  ('Augusto Conceição/Chiclete Com Banana', 9, 1),
#  ('Augusto Garcez/Nelson Cavaquinho', 7, 1),
#  ('Augusto/Craig Negoescu/Rocco Filho/Saara, Ze Carlos Da', 7, 1),
#  ('B. Carter/C. Layton/R. Ellsworth/R. Wynans/T. Shannon', 6, 1),
#  ('B. Cummings/G. Peterson/M.J. Kale/R. Bachman', 1, 1),
#  ('B. Daisley, O. Osbourne & R. Rhoads', 1, 2),
#  ('B. Guy', 6, 1),
#  ('B. de Filippi - F. Migliaci - Versão: Fred Jorge', 4, 1),
#  ('Baden Powell/Vinicius de Moraes', 7, 1),
#  ('Bahiano/Chuck Rio/Diego Blanco/Herbert Vianna', 7, 1),
#  ('Bahiano/Diego Blanco/Herbert Vianna', 7, 1),
#  ('Barrett Strong/Norman Whitfield', 14, 2),
#  ('Barrett Strong/Norman Whitfield/Roger Penzabene', 14, 1),
#  ('Ben E.King/James Bethea', 1, 1),
#  ('Ben Shepherd/Chris Cornell', 1, 1),
#  ('Ben Shepherd/Chris Cornell/Kim Thayil/Matt Cameron', 1, 1),
#  ('Bernardo Vilhena/Bino Farias/Da Gama/Lazão/Toni Garrido', 8, 1),
#  ('Bernardo Vilhena/Bino/Da Gama/Lazao/Toni Garrido', 8, 1),
#  ('Bernardo Vilhena/Da Gama/Lazao', 8, 1),
#  ('Bernardo Vilhena/Da Gama/Lazão', 8, 1),
#  ('Berry Gordy, Jr./Janie Bradford', 5, 1),
#  ('Bert Russell/Phil Medley', 5, 1),
#  ('Beto Gogo/Jessé Pai/Luiz Carlos/Zeca Pagodinho', 7, 1),
#  ('Beto Guedes, Márcio Borges', 7, 1),
#  ('Beto Guedes, Ronaldo Bastos', 7, 1),
#  ('Beto Guedes/Fernando Brant/L Borges', 7, 1),
#  ('Betty Newsome/James Brown', 14, 1),
#  ('Bi Ribeira/Herbert Vianna/João Barone', 7, 1),
#  ('Bi Ribeiro/Herbert Vianna/João Barone', 7, 1),
#  ('Big Bill Broonzy', 6, 1),
#  ('Bill Berry-Peter Buck-Mike Mills-Michael Stipe', 1, 14),
#  ('Bill Berry-Peter Buck-Mike Mills-Michael Stipe', 4, 11),
#  ('Bill Berry/Michael Stipe/Mike Mills/Peter Buck', 4, 11),
#  ('Bill Dees/Roy Orbison', 1, 1),
#  ('Bill Gould/Jon Hudson/Mike Bordin/Mike Patton', 4, 1),
#  ('Bill Gould/Jon Hudson/Mike Bordin/Mike Patton/Roddy Bottum', 4, 2),
#  ('Bill Gould/Mike Bordin/Mike Patton', 4, 2),
#  ('Bill Gould/Mike Patton', 4, 2),
#  ('Billie Joe Armstrong -Words Green Day -Music', 4, 20),
#  ('Billie Joe Armstrong, Mike Dirnt, Tré Cool', 4, 2),
#  ('Billie Joe Armstrong/Green Day', 4, 1),
#  ('Billy Cobham', 2, 7),
#  ('Billy Corgan', 4, 31),
#  ('Billy Duffy/Bob Rock/Ian Astbury', 1, 2),
#  ('Billy Duffy/Ian Astbury', 1, 9),
#  ('Billy Duffy/Ian Astbury/Marti Frederiksen/Mick Jones', 1, 1),
#  ('Billy Roberts', 1, 1),
#  ('Billy/Del James/W. Axl Rose/West Arkeen', 3, 1),
#  ('Bino Farias/Da Gama/Henry Lawes/Lazão/Toni Garrido/Winston Foser-Vers', 8, 1),
#  ('Bino Farias/Da Gama/Lazão/Pedro Luis/Toni Garrido', 8, 1),
#  ('Bino Farias/Da Gama/Lazão/Rás Bernardo', 8, 1),
#  ('Bino Farias/Da Gama/Lazão/Toni Garrido', 8, 4),
#  ('Bino Farias/Da Gamma/Lazão/Rás Bernard', 8, 1),
#  ('Bino/Da Gama/Lazao/Ras Bernardo', 8, 1),
#  ('Bino/Da Gama/Ras Bernardo', 8, 2),
#  ('Bino/Da Gama/Toni Garrido', 8, 1),
#  ('Bino/Da Gamma/Lazao/Toni Garrido', 8, 1),
#  ("Bizuca/Clóvis Pê/Gilson Bernini/Marelo D'Aguia", 7, 1),
#  ('Black Sabbath', 3, 1),
#  ('Blackmore, Gillan, Glover, Lord, Paice', 1, 7),
#  ('Blackmore, Glover, Turner', 1, 4),
#  ('Blackmore, Glover, Turner, Lord, Paice', 1, 4),
#  ('Blackmore/Coverdale', 1, 1),
#  ('Blackmore/Coverdale/Lord/Paice', 1, 1),
#  ('Blackmore/Gillan/Glover/Lord/Paice', 1, 1),
#  ('Blaze Bayley/David Murray/Steve Harris', 1, 1),
#  ('Blaze Bayley/Janick Gers', 1, 2),
#  ('Blaze Bayley/Janick Gers/Steve Harris', 1, 4),
#  ('Blaze Bayley/Steve Harris', 1, 1),
#  ('Bo Diddley', 5, 1),
#  ('Bob Cochran/Sharon Sheeley', 1, 1),
#  ('Bob Dylan', 3, 1),
#  ('Bob Rock/James Hetfield/Kirk Hammett/Lars Ulrich', 3, 11),
#  ('Bobby Byrd/James Brown/Ron Lenhoff', 14, 1),
#  ('Bolin/Coverdale', 1, 4),
#  ('Bolin/Coverdale/Paice', 1, 1),
#  ('Bolin/Hughes', 1, 1),
#  ('Bolin/Hughes/Lord', 1, 1),
#  ('Bombom/Ed Motta', 7, 1),
#  ('Bono', 1, 1),
#  ('Bono, The Edge, Adam Clayton, and Larry Mullen', 1, 12),
#  ('Bono/Clayton, Adam/Dylan, Bob/Mullen Jr., Larry/The Edge', 1, 1),
#  ('Bono/Clayton, Adam/Mullen Jr., Larry/The Edge', 1, 12),
#  ('Bossi/David Coverdale/Earl Slick', 1, 2),
#  ('Bourge/Phillips/Shelley', 3, 2),
#  ('Brad Shapiro/George Jackson/Robert Miller/Walter Shaw', 14, 1),
#  ('Branco Mello/Carlos Barmack/Ciro Pessoa/Marcelo Fromer/Toni Belloto', 4, 1),
#  ('Brian Eno, Bono, Adam Clayton, The Edge & Larry Mullen Jnr.', 10, 14),
#  ('Brian Eno/U2', 1, 1),
#  ('Brian Holland/Eddie Holland/Lamont Dozier', 14, 1),
#  ('Brian Holland/Freddie Gorman/Georgia Dobbins/Robert Bateman/William Garrett', 5, 1),
#  ('Brian May', 1, 2),
#  ('Bruce Dickinson', 3, 3),
#  ('Bruce Dickinson/David Murray', 1, 2),
#  ('Bruce Dickinson/David Murray', 3, 1),
#  ('Bruce Dickinson/David Murray/Steve Harris', 1, 1),
#  ('Bruce Dickinson/David Murray/Steve Harris', 3, 1),
#  ('Bruce Dickinson/David Murray/Steve Harris', 13, 2),
#  ('Bruce Dickinson/Janick Gers', 1, 3),
#  ('Bruce Dickinson/Janick Gers', 3, 2),
#  ('Bruce Dickinson/Janick Gers/Steve Harris', 1, 2),
#  ('Bruce Dickinson/Janick Gers/Steve Harris', 3, 1),
#  ('Bruce Dickinson/Janick Gers/Steve Harris', 13, 2),
#  ('Bruce Dickinson/Steve Harris', 3, 4),
#  ('Bruce Dickinson; Harris', 3, 1),
#  ('Bruce/Clapton', 6, 3),
#  ('Bryan Adams/Nikki Sixx/Scott Humphrey', 3, 1),
#  ('Buchanan, Wallis', 1, 1),
#  ('Buddy Guy', 6, 3),
#  ('Buzz Cason/Mac Gayden', 1, 1),
#  ('Béla Bartók', 24, 1),
#  ('C. A./C.A./Celso Alvim/Herbert Vianna/Mário Moura/Pedro Luís/Sidon Silva', 7, 1),
#  ('C. Burnett', 6, 1),
#  ('C. Cester', 4, 1),
#  ('C. Cester/C. Muncey', 4, 1),
#  ('C. Cester/C. Muncey/N. Cester', 4, 3),
#  ('C. Cester/N. Cester', 4, 4),
#  ('C. Muncey/N. Cester', 4, 3),
#  ('C.Burton', 3, 1),
#  ('Caetano Veloso', 4, 1),
#  ('Caetano Veloso', 7, 9),
#  ('Caetano Veloso - Djavan', 7, 1),
#  ('Caetano Veloso - Gilberto Gil', 4, 1),
#  ('Caetano Veloso - Waly Salomão', 7, 1),
#  ('Caetano Veloso e Gilberto Gil', 7, 11),
#  ('Cal Adan/Del Rey, Tension/Edu Casanova', 9, 1),
#  ('Cal Adan/Ferrugem/Julinho Carioca/Tríona Ní Dhomhnaill', 9, 1),
#  ('Cal Adan/Paulo Levi', 9, 1),
#  ('Cale/Clapton', 6, 1),
#  ('Carl Nielsen', 24, 1),
#  ('Carl Orff', 24, 1),
#  ('Carlinhos Brown', 7, 3),
#  ('Carlinhos Brown/Herbert Vianna', 7, 1),
#  ('Carlinhos Santana/Nelson Rufino', 7, 1),
#  ('Carlos Imperial/Edardo Araújo', 7, 1),
#  ('Carlos Imperial/Tim Maia', 7, 1),
#  ('Carlos Santana', 1, 3),
#  ('Carlos Santana & C. Thompson', 1, 1),
#  ('Carlos Santana & Dave Matthews', 1, 1),
#  ('Carlos Santana & KC Porter', 1, 1),
#  ('Carlos Santos/Ciro/Claudio Russo/Zé Luiz', 7, 1),
#  ('Carolyn Franklin and Sonny Saunders', 1, 1),
#  ('Caruso/Cleber/Deo/Osmar', 7, 1),
#  ('Cassiano Costa/Cintia Maviane/J.F./Lucas Costa', 9, 1),
#  ('Cave', 3, 1),
#  ('Charles Bobbitt/James Brown', 14, 2),
#  ('Charles Gavin/Marcelo Fromer/Sérgio Britto', 4, 1),
#  ('Charlie Midnight/Dan Hartman', 14, 1),
#  ('Chester Burnett/Jimmy Page/John Bonham/John Paul Jones/Robert Plant', 1, 1),
#  ('Chet Catallo', 2, 1),
#  ('Chico Amaral/Edgard Scandurra/Samuel Rosa', 1, 1),
#  ('Chico Amaral/Lelo Zanettik', 1, 1),
#  ('Chico Amaral/Samuel Rosa', 1, 6),
#  ('Chico Buarque', 7, 1),
#  ('Chico Science', 7, 23),
#  ('Chico Science/Dengue/Lúcio Maia', 7, 1),
#  ('Chris Cornell', 1, 10),
#  ('Chris Cornell', 23, 13),
#  ('Chris Cornell/Kim Thayil', 1, 4),
#  ('Chris Frantz/David Byrne/Jerry Harrison/Tina Weymouth', 7, 1),
#  ('Chris Robinson/Rich Robinson', 6, 18),
#  ('Chuck Berry', 5, 2),
#  ('Chuck Berry', 8, 1),
#  ('Cidade Negra', 8, 1),
#  ('Ciro Pressoa/Marcelo Fromer', 4, 1),
#  ('Clapton', 6, 4),
#  ('Clapton/Collins/Pappalardi', 6, 1),
#  ('Clapton/Dylan', 6, 1),
#  ('Clapton/F.eldman/Linn', 6, 1),
#  ('Clapton/Gordon', 6, 1),
#  ('Clapton/Harrison', 6, 1),
#  ('Clapton/J. J. Cale', 6, 1),
#  ('Clapton/Levy', 6, 1),
#  ('Clapton/Robert Johnson Arr: Eric Clapton', 6, 1),
#  ('Clapton/Trad. Arr. Clapton', 6, 1),
#  ('Clarke/Farren/Kilmister/Tayler', 3, 1),
#  ('Clarke/Kilmister/Tayler', 3, 3),
#  ('Clarke/Kilmister/Taylor', 3, 13),
#  ('Claudio Martins/David Lima/Kleber Rodrigues/Livre, Cesare Som', 7, 1),
#  ('Claudio Monteverdi', 24, 1),
#  ('Cliff Burton', 3, 1),
#  ('Collins/Van Zandt', 3, 1),
#  ('Cook/Coverdale', 1, 1),
#  ('Cornell, Commerford, Morello, Wilk', 4, 12),
#  ('Corumbá/José Gumarães/Venancio', 10, 1),
#  ('Coverdale', 1, 3),
#  ('Coverdale', 3, 2),
#  ('Coverdale/Hughes', 1, 1),
#  ('Coverdale/Hughes/Lord/Paice', 1, 1),
#  ('Coverdale/Lord/Paice', 1, 2),
#  ('Craig Ross/Lenny Kravitz', 1, 1),
#  ('Cub Coda/Michael Lutz', 3, 1),
#  ('Culmer/Exalt', 3, 1),
#  ('D. DeLeo/Kretz/R. DeLeo/Weiland', 1, 1),
#  ('D. DeLeo/Kretz/Weiland', 1, 2),
#  ('D. DeLeo/R. DeLeo/Weiland', 1, 1),
#  ('D.Coverdal/G.Hughes/Glenn Hughes/I.Paice/Ian Paice/J.Lord/John Lord', 1, 1),
#  ('D.Coverdale/G.Hughes/Glenn Hughes/I.Paice/Ian Paice/J.Lord/John Lord/R.Blackmore/Ritchie Blackmore', 1, 3),
#  ('D.Coverdale/G.Hughes/Glenn Hughes/J.Lord/John Lord', 1, 1),
#  ('D.Coverdale/G.Hughes/Glenn Hughes/R.Blackmore/Ritchie Blackmore', 1, 1),
#  ('D.Coverdale/R.Blackmore/Ritchie Blackmore', 1, 3),
#  ('Da Gama/Lazao/Toni Garrido', 8, 1),
#  ('Da Gama/Lazão/Rás Bernardo', 8, 1),
#  ('Da Gama/Toni Garrido', 8, 3),
#  ('Dadinho/Gilbreto Gomes/Gustavo/P.C. Portugal/R. Mocoto', 7, 1),
#  ('Dado Villa-Lobos', 7, 1),
#  ('Dado Villa-Lobos/Ico Ouro-Preto/Marcelo Bonfá', 7, 1),
#  ('Dado Villa-Lobos/Marcelo Bonfá', 7, 8),
#  ('Dale Evans', 1, 1),
#  ('Daniel Lanois', 4, 1),
#  ('Danzig', 3, 2),
#  ('Darius "Take One" Minwalla/Jon Auer/Ken Stringfellow/Matt Harris', 1, 2),
#  ('Dave Abbruzzese & Jeff Ament & Stone Gossard & Mike McCready & Eddie Vedder', 1, 3),
#  ('Dave Abbruzzese/Eddie Vedder/Jeff Ament/Mike McCready/Stone Gossard', 1, 12),
#  ('Dave Brubeck', 2, 1),
#  ('Dave Grohl', 1, 3),
#  ('Dave Grohl, Taylor Hawkins, Nate Mendel, Chris Shiflett', 1, 10),
#  ('Dave Grohl, Taylor Hawkins, Nate Mendel, Chris Shiflett/FOO FIGHTERS', 1, 10),
#  ('Dave Krusen/Stone Gossard', 1, 1),
#  ('Dave Kushner, Duff, Keith Nelson, Matt Sorum, Scott Weiland & Slash', 1, 1),
#  ('Dave Kushner, Duff, Matt Sorum, Scott Weiland & Slash', 1, 12),
#  ('Dave Murray; Steve Harris', 3, 1),
#  ('Dave, Taylor, Nate, Chris', 1, 10),
#  ('David Cook', 4, 1),
#  ('David Corrêa - Paulinho Carvalho - Carlos Sena - Bira do Ponto', 7, 1),
#  ('David Coverdale', 1, 5),
#  ('David Coverdale/Earl Slick', 1, 4),
#  ("David Murray/Paul Di'Anno/Steve Harris", 1, 2),
#  ("David Murray/Paul Di'Anno/Steve Harris", 3, 1),
#  ("David Murray/Paul Di'Anno/Steve Harris", 6, 1),
#  ('David Murray/Steve Harris', 1, 3),
#  ('David Murray/Steve Harris', 3, 3),
#  ('David Murray/Steve Harris', 13, 1),
#  ('De Beauport/Jagger/Richards', 1, 1),
#  ('Deacon', 1, 2),
#  ('Deacon, John', 1, 2),
#  ('Deacon, John/May, Brian', 1, 1),
#  ('Deacon/May/Mercury/Taylor', 3, 1),
#  ('Deaffy & R.A. Smith-Diesel', 1, 1),
#  ('Dean Brown, Dennis Chambers & Jim Beard', 2, 1),
#  ('Dean Deleo', 1, 1),
#  ('Deanna Brown/Deidra Jenkins/Yamma Brown', 14, 1),
#  ('Delroy "Chris" Cooper, Donovan Jackson, Earl Chinna Smith, Felix Howard, Gordon Williams, Luke Smith, Paul Watson & Wilburn Squiddley Cole', 9, 1),
#  ('Derrick McKenzie/Jay Kay/Toby Smith', 14, 1),
#  ('Diamond/Shermann', 3, 1),
#  ('Dick Holler', 14, 1),
#  ('Dickinson', 3, 3),
#  ('Dickinson/Smith', 3, 1),
#  ('Dito/Djalma Falcao/Ilha, Almir Da/Márcio André', 7, 1),
#  ('Di´Anno/Harris', 13, 1),
#  ('Djavan', 7, 12),
#  ('Djavan - Gabriel, O Pensador', 7, 1),
#  ('Do Vale, João/Luiz Wanderley', 7, 1),
#  ('Do Vale, Valverde/Gal Oliveira/Luciano Pinto', 9, 1),
#  ('Dolmayan, John/Malakian, Daron/Odadjian, Shavo', 3, 4),
#  ('Dolores Duran', 7, 1),
#  ('Domenil/J. Brito/Joaozinho/Rap, Marcelo Do', 7, 1),
#  ('Dominguinhos/Gilberto Gil', 10, 1),
#  ('Don Van Vliet', 1, 2),
#  ('Donato/Gilberto Gil', 7, 1),
#  ('Douglas/Neves, Vicente Das/Silva, Gilmar L./Toninho Gentil/Wantuir', 7, 1),
#  ('Doyle Bramhall/Stevie Ray Vaughan', 6, 4),
#  ('Dudu Nobre', 7, 1),
#  ('Dudu Nobre/Zeca Pagodinho', 7, 1),
#  ('Duff McKagan', 3, 1),
#  ('Duff McKagan/Slash/W. Axl Rose', 3, 2),
#  ('Dufort/Johnson/McAuliffe/Williams', 3, 1),
#  ('Dylan, Bob', 1, 1),
#  ('E. Schrody/J. Vasquez/L. Dimant', 17, 1),
#  ('E. Schrody/L. Dimant', 17, 6),
#  ('E. Schrody/L. Dimant/L. Muggerud', 17, 1),
#  ('E. Schrody/L. Freese/L. Muggerud', 17, 1),
#  ('E. Schrody/L. Muggerud', 17, 5),
#  ('E. Schrody/L. Muggerud/R. Medrano', 17, 1),
#  ('E. Schrody/R. Medrano', 17, 2),
#  ('E. Shrody', 1, 1),
#  ('E.Weiss', 1, 2),
#  ('Eale-Eye Cherry, M. Simpson, J. King & M. Nishita', 1, 1),
#  ('Eddie Casillas/Roy Z', 3, 1),
#  ('Eddie Cochran/Jerry Capehart', 5, 1),
#  ('Eddie Vedder', 1, 9),
#  ('Eddie Vedder', 4, 3),
#  ('Eddie Vedder & Mike McCready', 1, 1),
#  ('Eddie Vedder & Mike McCready', 4, 2),
#  ('Eddie Vedder & Stone Gossard', 1, 1),
#  ('Eddie Vedder/Jeff Ament/Matt Cameron/Mike McCready/Stone Gossard', 1, 1),
#  ('Edvard Grieg', 24, 1),
#  ('Edward Elgar', 24, 2),
#  ('Edward Van Halen, Alex Van Halen, David Lee Roth', 1, 2),
#  ('Edward Van Halen, Alex Van Halen, David Lee Roth, Michael Anthony', 1, 6),
#  ('Edward Van Halen, Alex Van Halen, Michael Anthony and David Lee Roth', 1, 9),
#  ('Edward Van Halen, Alex Van Halen, Michael Anthony,/Edward Van Halen, Alex Van Halen, Michael Anthony, David Lee Roth', 1, 2),
#  ('Edward Van Halen, Alex Van Halen, Michael Anthony,/Edward Van Halen, Alex Van Halen, Michael Anthony, Sammy Hagar', 1, 4),
#  ('Emerson Villani', 7, 1),
#  ('Enotris Johnson/Little Richard/Robert "Bumps" Blackwell', 5, 1),
#  ('Erasmo Carlos/Roberto Carlos', 4, 1),
#  ('Eric Clapton', 6, 2),
#  ('Eric Clapton, Jim Gordon', 6, 1),
#  ('Eric Clapton, Robert Cray', 6, 1),
#  ('Eric Clapton, Will Jennings', 6, 1),
#  ('Erik Satie', 24, 1),
#  ('Eugene McDaniel', 6, 1),
#  ('Eurreal Montgomery', 6, 1),
#  ('F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. Dirkscneider & W. Hoffman', 1, 1),
#  ('F. Baltes, S. Kaufman, U. Dirkscneider & W. Hoffman', 1, 1),
#  ('F. Olivera', 1, 1),
#  ('Faith No More', 4, 10),
#  ('Faithfull/Jagger/Richards', 1, 1),
#  ('Fausto Fawcett/Samuel Rosa', 1, 1),
#  ('Fausto Nilo - Armandinho', 7, 1),
#  ('Fausto Nilo/Moraes Moreira/Pepeu Gomes', 8, 1),
#  ('Fayyaz Virgi/Richard Bull', 2, 1),
#  ('Fito Paez/Herbert Vianna', 7, 1),
#  ('Flavio Bororo/Paulo Apparicio/Wagner Alves/Zeca Sereno', 7, 1),
#  ('Folclore', 7, 1),
#  ('Foo Fighters', 4, 11),
#  ('Frank Zappa', 1, 7),
#  ('Franz Joseph Haydn', 24, 1),
#  ('Franz Schubert', 24, 2),
#  ('Fred Wesley/James Brown', 14, 1),
#  ('Fred Wesley/James Brown/Joseph Mims', 14, 1),
#  ('Freddie Mercury', 1, 1),
#  ('Freddie Mercury & John Deacon', 1, 1),
#  ('Freddy James, Jimmy hogarth & Larry Stock', 9, 1),
#  ('Frédéric Chopin', 24, 1),
#  ('Full Force/James Brown', 14, 1),
#  ('Fábio Nolasco/Gal Sales/Ivan Brasil', 9, 1),
#  ('G Harvey/R Hope-Taylor', 2, 1),
#  ('G M Sumner', 1, 14),
#  ('Gabriel Fauré', 24, 1),
#  ('Galley', 3, 1),
#  ('Garay, Ricardo Engels/Luca Predabom/Ludwig, Carlos Henrique/Maurício Vieira', 9, 1),
#  ('Geddy Lee And Alex Lifeson/Geddy Lee And Neil Peart/Rush', 1, 14),
#  ('Gelder, Nick van', 1, 1),
#  ('Gene Simmons', 1, 7),
#  ('Gene Simmons, S. Coronel', 1, 2),
#  ('Gene Simmons, Stephen Coronel', 1, 1),
#  ('Genival Cassiano', 7, 1),
#  ('Genival Cassiano/Silvio Rochael', 7, 1),
#  ('George Duke', 2, 1),
#  ('George Frideric Handel', 24, 3),
#  ('Georges Bizet', 24, 1),
#  ('Gerry DeVeaux/Terry Britten', 1, 1),
#  ('Giacomo Puccini', 24, 2),
#  ('Gil Evans', 2, 2),
#  ('Gilberto Gil', 7, 19),
#  ('Gilberto Gil', 8, 1),
#  ('Gilberto Gil', 10, 3),
#  ('Gilberto Gil - Caetano Veloso', 4, 1),
#  ('Gillan/Glover/Lord/Nix - Blackmore/Paice', 1, 1),
#  ('Gillan/Glover/Lord/Paice', 1, 1),
#  ('Gilmour, Mason, Wright, Waters', 1, 1),
#  ('Gilmour, Waters', 1, 1),
#  ('Gilson Mendonça/Michel', 7, 1),
#  ('Giovanni Pierluigi da Palestrina', 24, 1),
#  ('Giuseppe Verdi', 24, 1),
#  ('Gonzaga Jr', 7, 1),
#  ('Gonzaga Jr.', 7, 3),
#  ('Gonzaga Jr/Gonzaguinha', 7, 1),
#  ('Gonzaguinha', 7, 1),
#  ('Graham Harvey', 2, 1),
#  ('Grazielle/Roque Ferreira', 7, 1),
#  ('Green Day', 4, 7),
#  ('Greg Macainsh', 1, 1),
#  ('Gregorio Allegri', 24, 1),
#  ('Guga/Marquinho Lessa/Tuninho Professor', 7, 1),
#  ('Guio De Morais E Seus "Parentes"/Luiz Gonzaga', 10, 1),
#  ('Gule/Jorge 101/Lequinho/Luiz Piao', 7, 1),
#  ('Gustav Holst', 24, 1),
#  ('Gustav Mahler', 24, 1),
#  ('H. Spina, J. Elliott', 2, 2),
#  ('Habib Koité', 16, 2),
#  ('Harris', 3, 7),
#  ('Harris/Di Anno', 3, 1),
#  ('Harris/Paul Di´Anno', 6, 2),
#  ('Harris/Tatler', 3, 4),
#  ('Harry Lawes/Winston Foster-Vers', 8, 1),
#  ('Hawkins-Lewis-Broadwater', 1, 1),
#  ('Heath/Robinson', 3, 1),
#  ('Hector Berlioz', 24, 1),
#  ('Hendrix, Jimi', 1, 1),
#  ('Henry Hirsch/Lenny Kravitz', 1, 1),
#  ('Henry Kirssch/Lenny Kravitz/S. Pasch A. Krizan', 1, 1),
#  ('Henry Purcell', 24, 2),
#  ('Henryk Górecki', 24, 1),
#  ('Herbert Vianna', 7, 18),
#  ('Herbert Vianna', 8, 1),
#  ('Herbert Vianna/Paulo Sérgio Valle', 7, 1),
#  ('Herbert Vianna/Tet Tillett', 7, 1),
#  ('Herbert Vianna/Tetê Tillet', 7, 1),
#  ('Hetfield, Ulrich', 3, 6),
#  ('Hetfield, Ulrich, Hammett', 3, 6),
#  ('Hetfield, Ulrich, Newsted', 3, 1),
#  ('Holocaust', 3, 1),
#  ('Humberto Teixeira/Luiz Gonzaga', 10, 4),
#  ('Hyldon', 7, 1),
#  ('I. Toure, S. Tidiane Toure, Carlos Santana & K. Perazzo', 1, 1),
#  ('Ian Gillan, Roger Glover, Jon Lord, Steve Morse, Ian Paice', 1, 12),
#  ('Ian Gillan/Ian Paice/Jon Lord/Ritchie Blckmore/Roger Glover', 1, 7),
#  ('Ian Stewart/John Bonham/John Paul Jones/Mrs. Valens/Robert Plant', 1, 1),
#  ('Igor Stravinsky', 24, 1),
#  ('Ira Gershwin, Kurt Weill', 2, 1),
#  ('Isham Jones & Marty Symes', 9, 1),
#  ('Ivan Kral/Patti Smith', 1, 1),
#  ('Ivy Hunter/Stevie Wonder', 14, 1),
#  ('Ivy Hunter/William "Mickey" Stevenson', 14, 1),
#  ('Ivy Jo Hunter/Marvin Gaye/William Stevenson', 1, 1),
#  ("Izzy Stradlin'", 3, 1),
#  ("Izzy Stradlin'/W. Axl Rose", 3, 3),
#  ('J B Lenoir/Willie Dixon', 1, 2),
#  ('J. B. Lenoir/Willie Dixon', 1, 1),
#  ('J. C. Fogerty', 1, 17),
#  ('J. Carisi', 2, 2),
#  ('J. Kay/Jay Kay', 15, 2),
#  ('J. Purdell, M. Inez, O. Osbourne, R. Castillo & Z. Wylde', 1, 1),
#  ('J. Satriani', 1, 4),
#  ('J.C. Fogerty', 1, 20),
#  ('J.Hetfield/L.Ulrich', 3, 2),
#  ('J.J. Johnson', 2, 1),
#  ('J.J. Johnson/R. Troup, L. Worth', 2, 1),
#  ('J.r.Bertami/Parana', 7, 1),
#  ('Jack Yellen/Milton Ager', 1, 1),
#  ('Jagger/Richards', 1, 35),
#  ('Jagger/Richards/Oldham', 1, 1),
#  ('James Brown', 14, 3),
#  ('James Brown & Bobby Byrd', 2, 1),
#  ('James Brown/Johnny Terry', 14, 1),
#  ('James Brown/Tim Maia', 7, 1),
#  ('James Hetfield', 3, 1),
#  ('James Hetfield & Lars Ulrich', 3, 1),
#  ('James Hetfield and Lars Ulrich', 3, 2),
#  ('James Hetfield, Lars Ulrich', 3, 11),
#  ('James Hetfield, Lars Ulrich & Jason Newsted', 3, 1),
#  ('James Hetfield, Lars Ulrich & Kirk Hammett', 3, 2),
#  ('James Hetfield, Lars Ulrich and Cliff Burton', 3, 1),
#  ('James Hetfield, Lars Ulrich and Jason Newsted', 3, 1),
#  ('James Hetfield, Lars Ulrich and Kirk Hammett', 3, 6),
#  ('James Hetfield, Lars Ulrich, Dave Mustaine', 3, 4),
#  ('James Hetfield, Lars Ulrich, Kirk Hammett', 3, 7),
#  ('James Iha', 4, 1),
#  ('Janick Gers/Steve Harris', 1, 7),
#  ('Janick Gers/Steve Harris', 3, 1),
#  ('Janick Gers/Steve Harris', 13, 1),
#  ('Jauperi/Zeu Góes', 9, 1),
#  ('Jay Beckenstein', 2, 3),
#  ('Jay Hawkins', 1, 1),
#  ('Jay Kay', 14, 4),
#  ('Jay Kay/Kay, Jay', 1, 2),
#  ('Jay Kay/Toby Smith', 14, 5),
#  ('Jean Paul Maunick', 2, 2),
#  ('Jean Sibelius', 24, 1),
#  ('Jeff Ament', 1, 5),
#  ('Jeff Ament', 4, 2),
#  ('Jeff Ament & Eddie Vedder', 1, 1),
#  ('Jeff Ament & Stone Gossard & Jack Irons & Mike McCready & Eddie Vedder', 1, 1),
#  ('Jeff Ament/Mike McCready/Stone Gossard', 1, 1),
#  ('Jeff Ament/Stone Gossard', 1, 3),
#  ('Jeremy Wall', 2, 4),
#  ('Jerry Cantrell', 1, 6),
#  ('Jerry Cantrell, Layne Staley', 1, 4),
#  ('Jerry Cantrell, Michael Starr, Layne Staley', 1, 1),
#  ('Jerry Cantrell, Michael Starr, Sean Kinney', 1, 1),
#  ('Jerry Lynn Williams', 6, 1),
#  ('Jerry Ragavoy', 1, 1),
#  ('Jesse Ed Davis III/Taj Mahal', 1, 1),
#  ('Jesse Fuller', 6, 1),
#  ('Jim Beard', 2, 2),
#  ('Jim Beard & Jon Herington', 2, 1),
#  ('Jimi Hendrix', 1, 16),
#  ('Jimmy Cox', 6, 1),
#  ('Jimmy Forrest/Lewis C. Simpkins/Oscar Washington', 14, 1),
#  ('Jimmy Page', 1, 6),
#  ('Jimmy Page & Robert Plant', 1, 1),
#  ('Jimmy Page, Robert Plant', 1, 15),
#  ('Jimmy Page, Robert Plant & John Paul Jones', 1, 3),
#  ('Jimmy Page, Robert Plant, Charlie Jones, Michael Lee', 1, 12),
#  ('Jimmy Page, Robert Plant, John Bonham', 1, 1),
#  ('Jimmy Page, Robert Plant, John Bonham, John Paul Jones', 1, 1),
#  ('Jimmy Page, Robert Plant, John Paul Jones', 1, 5),
#  ('Jimmy Page, Robert Plant, John Paul Jones, John Bonham', 1, 4),
#  ('Jimmy Page, Robert Plant, John Paul Jones, John Bonham, Memphis Minnie', 1, 1),
#  ('Jimmy Page/Jimmy Page & Robert Plant/Robert Plant', 1, 4),
#  ('Jimmy Page/John Bonham/John Estes/John Paul Jones/Robert Plant', 1, 1),
#  ('Jimmy Page/John Bonham/John Paul Jones', 1, 6),
#  ('Jimmy Page/John Bonham/John Paul Jones/Robert Plant/Willie Dixon', 1, 1),
#  ('Jimmy Page/John Paul Jones', 1, 1),
#  ('Jimmy Page/Led Zeppelin', 1, 1),
#  ('Jimmy Page/Robert Johnson/Robert Plant', 1, 1),
#  ('Jimmy Page/Robert Plant', 1, 12),
#  ('Jimmy and Vella Cameron', 1, 1),
#  ('Joe Strummer/Mick Jones', 4, 9),
#  ('Johann Pachelbel', 24, 1),
#  ('Johann Sebastian Bach', 24, 7),
#  ('Johann Strauss II', 24, 1),
#  ('John Adams', 24, 1),
#  ('John Bonham', 1, 2),
#  ('John Bonham, John Paul Jones, Jimmy Page', 1, 1),
#  ('John Bonham/John Paul Jones', 1, 6),
#  ('John Bonham/John Paul Jones/Robert Plant', 1, 2),
#  ('John Bonham/John Paul Jones/Robert Plant/Willie Dixon', 1, 1),
#  ('John Brim', 1, 1),
#  ('John Deacon', 1, 1),
#  ('John Dowland', 24, 1),
#  ('John Entwistle', 1, 1),
#  ('John Entwistle/Pete Townshend', 1, 5),
#  ('John Lennon, Paul McCartney', 7, 1),
#  ('John Paul Jones', 1, 2),
#  ('John Paul Jones & Robert Plant', 1, 1),
#  ('John Paul Jones, Jimmy Page & Robert Plant', 1, 1),
#  ('John Paul Jones/Robert Plant', 1, 6),
#  ('John Scofield', 2, 1),
#  ('John Scofield, Robert Aries, Milton Chambers and Gary Grainger', 2, 1),
#  ('John and William Valentine', 1, 1),
#  ('Jon Herington', 2, 1),
#  ('Jon Hudson/Mike Bordin/Mike Patton', 4, 1),
#  ('Jon Hudson/Mike Patton', 4, 1),
#  ('Jones/Sirotto/Smith', 3, 1),
#  ('Jorge Aragão/Zeca Pagodinho', 7, 1),
#  ('Jorge Ben', 7, 2),
#  ('Jorge Cardoso/Pierre Onasis', 9, 1),
#  ('Jorge Vercilo/Jota Maranhao', 7, 1),
#  ('João Suplicy', 16, 14),
#  ('Julian Crampton', 2, 1),
#  ('K.Hammett', 3, 5),
#  ('KC Porter & JB Eckl', 1, 1),
#  ('Karol Szymanowski', 24, 1),
#  ('Karsh Kale', 15, 1),
#  ('Karsh Kale/Vishal Vaid', 15, 1),
#  ('Keith Richards/Mick Jagger', 4, 1),
#  ('Kelly, Mosley, Rothery, Trewaves', 1, 10),
#  ('Kenny Gamble and Leon Huff', 1, 1),
#  ('Kevin Robinson', 2, 1),
#  ('Kevin Robinson/Richard Bull', 2, 1),
#  ('Killing Joke', 3, 1),
#  ('Kretz/R. DeLeo/Weiland', 1, 1),
#  ('Kurt Cobain', 1, 26),
#  ('Kurt Weill', 24, 1),
#  ('L. Delibes', 2, 1),
#  ('L. Hill', 1, 1),
#  ('L. Kerslake, O. Osbourne, R. Daisley & R. Rhoads', 1, 1),
#  ('L. Kilmister, O. Osbourne & Z. Wylde', 1, 1),
#  ('L. Muggerud', 17, 2),
#  ('Larry Williams', 5, 2),
#  ('Lennon, John/McCartney, Paul', 1, 1),
#  ('Lenny Kravitz', 1, 9),
#  ('Lenny Kravitz/Slash', 1, 1),
#  ('Leão, Rodrigo F./Lô Borges/Samuel Rosa', 1, 1),
#  ('Leão, Rodrigo F./Samuel Rosa', 1, 1),
#  ('Little Richard', 5, 1),
#  ('Lowman Pauling', 14, 1),
#  ('Luca Gusella', 2, 1),
#  ('Luciana Souza', 7, 1),
#  ('Lucina/Luli', 9, 1),
#  ('Ludwig van Beethoven', 24, 5),
#  ('Luiz Carlos/Oberdan', 7, 1),
#  ('Luiz Gonzaga/Zé Dantas', 10, 1),
#  ('Luiz Melodia/Ricardo Augusto', 7, 1),
#  ('Luiz Wanderley/Paulo Levi', 9, 1),
#  ('Luke Smith', 9, 1),
#  ('Lulu Santos', 7, 1),
#  ('Lulu Santos', 8, 1),
#  ('Lô Borges, Fernando Brant', 7, 1),
#  ('Lô Borges, Márcio Borges, Fernando Brant', 7, 1),
#  ('M. Itaal Shur & Rob Thomas', 1, 1),
#  ('M.Babatunde Olantunji', 1, 1),
#  ('Mabins, Macie/Magee, Sterling/Robinson, Bobby', 1, 1),
#  ('Macelo Yuka/O Rappa', 7, 1),
#  ('Manuca/Raimundinho DoAcordion/Targino Godim', 10, 1),
#  ('Marc-Antoine Charpentier', 24, 1),
#  ('Marco Tulio Lara/Rogerio Flausino', 7, 1),
#  ('Marcos Valle', 7, 1),
#  ('Marisa Monte/Nando Reis', 8, 2),
#  ('Marisa Monte/poema de Octavio Paz/versão: Haroldo de Campos', 7, 1),
#  ('Mark Ronson', 14, 1),
#  ('Marley', 6, 1),
#  ('Marsden', 3, 1),
#  ('Marsden/Moody', 3, 1),
#  ('Marvin Gaye', 14, 4),
#  ('Mason, Waters, Wright, Gilmour', 1, 1),
#  ('Mason/Waters, Gilmour, Wright', 1, 1),
#  ('Matt Cameron', 1, 3),
#  ('Matt Cameron & Mike McCready', 4, 1),
#  ('Matt Rowe & Stefan Skarbek', 9, 1),
#  ('Mauro Diniz/Ratino Sigem', 7, 1),
#  ('Maxton Gig Beesley Jnr.', 2, 1),
#  ('May', 1, 4),
#  ('May, Brian', 1, 4),
#  ('McKinley Morgenfield (Muddy Waters)', 6, 1),
#  ('Mercury', 1, 3),
#  ('Mercury, Freddie', 1, 10),
#  ('Metallica', 3, 8),
#  ('Michael Jackson', 23, 1),
#  ('Mick Hucknall', 1, 7),
#  ('Mick Hucknall and Fritz McIntyre', 1, 2),
#  ('Mick Hucknall and Lamont Dozier', 1, 1),
#  ('Mick Hucknall and Neil Moss', 1, 1),
#  ('Mick Jagger, Keith Richard', 1, 1),
#  ('Mick Jones/Traditional arr. Joe Strummer', 4, 1),
#  ('Mick Mars/Nikki Sixx', 3, 3),
#  ('Mick Mars/Nikki Sixx/Tommy Lee', 3, 2),
#  ('Mick Mars/Nikki Sixx/Tommy Lee/Vince Neil', 3, 3),
#  ('Mike Bordin, Billy Gould, Mike Patton', 1, 10),
#  ('Mike Bordin, Billy Gould, Mike Patton, Trey Spruance', 1, 5),
#  ('Mike Dint, Billie Joe, Tré Cool', 4, 2),
#  ('Mike Dirnt -Words Green Day -Music', 4, 1),
#  ('Mike Dirnt/Tré Cool', 4, 1),
#  ('Mike McCready', 4, 1),
#  ('Mike McCready & Stone Gossard', 4, 1),
#  ('Mike Patton', 4, 3),
#  ('Miles Davis', 2, 23),
#  ('Miles Davis, Gil Evans', 2, 1),
#  ('Milton Nascimento', 7, 1),
#  ('Milton Nascimento, Caetano Veloso', 7, 2),
#  ('Milton Nascimento, Fernando Brant', 7, 9),
#  ('Milton Nascimento, Márcio Borges', 7, 1),
#  ('Milton Nascimento, Ronaldo Bastos', 7, 3),
#  ('Molaney/Morris/Roberts/Wainwright', 3, 2),
#  ('Moody', 3, 1),
#  ('Morais', 7, 1),
#  ('Murilão', 7, 1),
#  ('Murray  Dave', 6, 1),
#  ('Mutantes', 4, 1),
#  ('Mônica Marianno', 16, 12),
#  ('N. Cester', 4, 1),
#  ('Nando Reis', 4, 2),
#  ('Nando Reis', 7, 1),
#  ('Nando Reis/Samuel Rosa', 1, 1),
#  ('Nanker Phelge', 1, 1),
#  ('Ned Fairchild', 5, 1),
#  ('Nei Lopes/Wilson Moreira', 7, 1),
#  ('Neil Young', 1, 1),
#  ('Nelson Angelo', 7, 1),
#  ('Niccolò Paganini', 24, 1),
#  ('Nickolas Ashford & Valerie Simpson', 14, 1),
#  ('Nikki Sixx', 3, 5),
#  ('Nikki Sixx/Tommy Lee/Vince Neil', 3, 2),
#  ('Nikolai Rimsky-Korsakov', 24, 1),
#  ('Nirvana', 1, 3),
#  ('O. Osbourne', 1, 1),
#  ('O. Osbourne, R. Daisley, R. Rhoads', 3, 9),
#  ('O. Osbourne, R. Daisley, R. Rhoads, L. Kerslake', 3, 1),
#  ('Orestes Barbosa-Sílvio Caldas', 4, 1),
#  ('Os Mutantes - Arnolpho Lima Filho', 4, 1),
#  ('Page, Jones', 1, 1),
#  ('Patrick Claher/Richard Bull', 2, 1),
#  ("Paul Di'Anno/Steve Harris", 1, 3),
#  ("Paul Di'Anno/Steve Harris", 3, 2),
#  ("Paul O'duffy", 14, 1),
#  ('Paul Stanley', 1, 5),
#  ('Paul Stanley, Ace Frehley', 1, 2),
#  ('Paul Stanley, B. Ezrin', 1, 1),
#  ('Paul Stanley, B. Ezrin, K. Fowley', 1, 1),
#  ('Paul Stanley, Bob Ezrin, Kim Fowley', 1, 1),
#  ('Paul Stanley, Gene Simmons', 1, 3),
#  ('Paul Stanley, Gene Simmons, B. Ezrin', 1, 1),
#  ('Paul Stanley, Gene Simmons, Bob Ezrin, Lewis Reed', 1, 1),
#  ('Paul Stanley, Gene Simmons, Rus Ballard, Bob Ezrin', 1, 1),
#  ('Paul Stanley, Vincent Cusano', 1, 1),
#  ('Paul Stanley, Vincent Poncia', 1, 2),
#  ('Paul Stanley, Vincent Poncia, Desmond Child', 1, 1),
#  ('Paulinho Rezende/Toninho Geraes', 7, 1),
#  ('Paulo Levi/W. Rangel', 9, 1),
#  ('Pearl Jam', 1, 2),
#  ('Pearl Jam & Eddie Vedder', 1, 1),
#  ('Peninha', 7, 1),
#  ('Pete Townshend', 1, 13),
#  ('Pete Townshend, Roger Daltrey', 1, 1),
#  ('Peter Criss, Stan Penridge, Bob Ezrin', 1, 1),
#  ('Peter Ilyich Tchaikovsky', 24, 1),
#  ('Philip Glass', 10, 1),
#  ('Pietro Antonio Locatelli', 24, 1),
#  ('Pietro Mascagni', 24, 1),
#  ('Queen', 1, 9),
#  ('Queen & David Bowie', 1, 1),
#  ('R. Carless', 2, 1),
#  ('R. DeLeo/Weiland', 1, 6),
#  ('R. Rhoads', 3, 1),
#  ('R. Taha, Carlos Santana & T. Lindsay', 1, 1),
#  ('R. Troup, L. Worth', 2, 1),
#  ('R.E.M.', 4, 16),
#  ('Ralph Vaughan Williams', 24, 1),
#  ('Ratinho/Zeca Pagodinho', 7, 1),
#  ('Ray Davies', 1, 2),
#  ('Red Hot Chili Peppers', 1, 12),
#  ('Renato Russo', 7, 20),
#  ('Renato Russo - Marcelo Bonfá', 7, 1),
#  ('Renato Russo - Marisa Monte', 7, 1),
#  ('Richard Bull', 2, 2),
#  ('Richard Poindexter & Robert Poindexter', 14, 1),
#  ('Richard Wagner', 24, 1),
#  ('Richie Blackmore, Ian Gillian, Roger Glover', 1, 2),
#  ('Richie Blackmore, Ian Gillian, Roger Glover, Ian Paice', 1, 1),
#  ('Richie Blackmore, Ian Gillian, Roger Glover, Jon Lord', 1, 2),
#  ('Richie Blackmore, Ian Gillian, Roger Glover, Jon Lord, Ian Paice', 1, 5),
#  ('Rick Strauss', 2, 1),
#  ('Rita Lee - Arnaldo Baptista - Sérgio Baptista', 4, 1),
#  ('Ritchie Blackmore, Ian Gillan, Roger Glover, Jon Lord, Ian Paice', 1, 7),
#  ('Robby Krieger, Ray Manzarek, John Densmore, Jim Morrison', 1, 9),
#  ('Robert Geddins/Ron Badger/Sheldon Feinberg', 6, 1),
#  ('Robert Johnson', 4, 1),
#  ('Robert Johnson', 6, 2),
#  ('Robert Plant', 1, 13),
#  ('Robert Plant & John Paul Jones', 1, 1),
#  ('Robert Rogers/Warren "Pete" Moore/William "Mickey" Stevenson', 14, 1),
#  ('Rodolfo', 4, 10),
#  ('Roger Taylor', 1, 2),
#  ('Roy Z', 3, 8),
#  ('S. Penridge, Bob Ezrin, Peter Criss', 1, 1),
#  ('Salaam Remi', 9, 2),
#  ('Samuel Barber', 24, 1),
#  ('Samuel Rosa', 1, 11),
#  ('Santana', 1, 1),
#  ('Seger', 3, 1),
#  ('Sergei Prokofiev', 24, 1),
#  ('Slash/W. Axl Rose', 3, 1),
#  ('Smith, Toby', 1, 6),
#  ('Smith/Dickinson', 3, 3),
#  ('Smokey Robinson/Warren "Pete" Moore', 14, 1),
#  ('Sonny Boy Williamson [I]', 6, 1),
#  ('Sonny Curtis', 4, 1),
#  ('Soundgarden', 1, 1),
#  ('South', 1, 1),
#  ('Steve Harris', 1, 26),
#  ('Steve Harris', 3, 36),
#  ('Steve Harris', 6, 5),
#  ('Steve Harris', 13, 13),
#  ('Steven Tyler, Desmond Child', 1, 1),
#  ('Steven Tyler, Jim Vallance', 1, 2),
#  ('Steven Tyler, Joe Perry', 1, 1),
#  ('Steven Tyler, Joe Perry, Desmond Child', 1, 3),
#  ('Steven Tyler, Joe Perry, Jack Blades, Tommy Shaw', 1, 1),
#  ('Steven Tyler, Joe Perry, Jim Vallance', 1, 1),
#  ('Steven Tyler, Joe Perry, Jim Vallance, Holly Knight', 1, 1),
#  ('Steven Tyler, Joe Perry, Mark Hudson', 1, 1),
#  ('Steven Tyler, Joe Perry, Taylor Rhodes', 1, 2),
#  ('Steven Tyler, Richie Supa', 1, 1),
#  ('Steven Tyler, Tom Hamilton', 1, 1),
#  ('Stevie Nicks', 4, 1),
#  ('Stevie Ray Vaughan', 6, 2),
#  ('Stone Gossard', 1, 5),
#  ('Stone Gossard', 4, 3),
#  ('Stone Gossard & Eddie Vedder', 1, 2),
#  ('Stone Gossard & Eddie Vedder & Jeff Ament & Mike McCready', 1, 1),
#  ('Stuard Zender/Toby Smith', 15, 1),
#  ('Stuart Zender', 15, 1),
#  ('Sully Erna', 3, 10),
#  ('Sully Erna; Tony Rombola', 3, 2),
#  ('Sweet Savage', 3, 1),
#  ('Sykes', 3, 4),
#  ('Sylvester Stewart', 2, 1),
#  ('Sérgio Britto', 4, 2),
#  ('Sérgio Britto/Toni Bellotto', 4, 1),
#  ('Tankian, Serj', 3, 7),
#  ('Taylor', 1, 2),
#  ('Ted Wright', 14, 1),
#  ('Terry Bozzio, Steve Stevens, Tony Levin', 1, 7),
#  ('The Clash', 4, 7),
#  ('The Tea Party', 4, 24),
#  ('Thomas Tallis', 24, 1),
#  ('Tim Maia', 7, 9),
#  ('Titãs', 4, 22),
#  ('Toby Smith', 14, 1),
#  ('Toby Smith', 15, 6),
#  ('Toby Smith/Wallis Buchanan', 15, 1),
#  ('Tom Jobim - Newton Mendoça', 7, 1),
#  ('Toni Bellotto', 4, 1),
#  ('Toninho Horta', 7, 1),
#  ('Tony Iommi, Bill Ward, Geezer Butler, Ozzy Osbourne', 3, 10),
#  ('Tony Iommi, Bill Ward, Geezer Butler, Ozzy Osbourne', 4, 1),
#  ('Tradicional', 7, 1),
#  ('Traditional', 1, 2),
#  ('Traditional', 3, 1),
#  ('Traditional', 6, 1),
#  ('Turner, Held, Greenwood', 1, 1),
#  ('U2', 1, 44),
#  ("U2 & Daragh O'Toole", 1, 1),
#  ('U2 & Van Dyke Parks', 1, 1),
#  ('U2; Bono', 1, 8),
#  ('U2; Bono & Edge, The', 1, 1),
#  ('U2; Edge, The', 1, 1),
#  ('Ulrich', 3, 7),
#  ('Unknown', 1, 168),
#  ('Unknown', 2, 51),
#  ('Unknown', 3, 44),
#  ('Unknown', 4, 31),
#  ('Unknown', 7, 309),
#  ('Unknown', 8, 27),
#  ('Unknown', 9, 26),
#  ('Unknown', 10, 16),
#  ('Unknown', 11, 15),
#  ('Unknown', 13, 3),
#  ('Unknown', 14, 10),
#  ('Unknown', 15, 17),
#  ('Unknown', 17, 16),
#  ('Unknown', 18, 13),
#  ('Unknown', 19, 93),
#  ('Unknown', 20, 26),
#  ('Unknown', 21, 64),
#  ('Unknown', 22, 17),
#  ('Unknown', 23, 26),
#  ('Unknown', 24, 6),
#  ('Van Halen', 1, 15),
#  ('Vandenberg', 3, 4),
#  ('Vários', 7, 17),
#  ('W. Axl Rose', 3, 4),
#  ('W. Jean, J. Duplessis, Carlos Santana, K. Perazzo & R. Rekow', 1, 1),
#  ('W.Correa', 1, 1),
#  ('Wagner Tiso, Milton Nascimento', 7, 1),
#  ('Waters', 1, 3),
#  ('Waters, Wright', 1, 1),
#  ('Weill-Brecht', 1, 1),
#  ('Whitfield-Strong', 1, 1),
#  ('William "Mickey" Stevenson', 14, 1),
#  ('William Byrd', 24, 1),
#  ('Willie Dixon', 1, 4),
#  ('Willie Dixon', 6, 4),
#  ('Willie Dixon, C. Burnett', 1, 1),
#  ('Wolfgang Amadeus Mozart', 24, 4),
#  ('Wolfgang Amadeus Mozart', 25, 1),
#  ('Wright, Waters', 1, 1),
#  ('alan bergman/marilyn bergman/peggy lipton jones/quincy jones', 12, 1),
#  ('antonio carlos jobim/norman gimbel/vinicius de moraes', 12, 1),
#  ('bart howard', 12, 1),
#  ('bert brecht/kurt weill/marc blitzstein', 12, 1),
#  ('berthold kaempfert/charles singleton/eddie snyder', 12, 1),
#  ('carl sigman/gilbert becaud/pierre leroyer', 12, 1),
#  ('carolyn leigh/cy coleman', 12, 1),
#  ('carson c. parks', 12, 1),
#  ('claude françois/gilles thibault/jacques revaux/paul anka', 12, 1),
#  ('cole porter', 12, 2),
#  ('dean kay thompson/kelly gordon', 12, 1),
#  ('ervin drake', 12, 1),
#  ('fred ebb/john kander', 12, 1),
#  ('george gershwin/ira gershwin', 12, 1),
#  ('hans bradtke/heinz meier/johnny mercer', 12, 1),
#  ('henry mancini/johnny mercer', 12, 1),
#  ('ian paice/jon lord', 1, 1),
#  ('jim croce', 12, 1),
#  ('jimmy van heusen/sammy cahn', 12, 3),
#  ('jon lord/roger glover', 1, 2),
#  ('lorenz hart/richard rodgers', 12, 1),
#  ('orlando murden/ronald miller', 12, 1),
#  ('rod mckuen', 12, 1),
#  ('roger glover', 1, 7)]

# %% [markdown]
# #### Ex. 3 - SUM()
# Who are the top 5 composers who wrote the most music, by length of time? Show time in minutes.

# %%
# %%sql
# -- Write Your Query here

# %% [markdown]
# #### Ex. 4 - MAX()
# What is the longest song? Show the track name, composer, and time in minutes.

# %%
# %%sql
# -- Write Your Query here

# %% [markdown]
# #### Ex. 5 - HAVING
# Show how many songs each composer wrote in each genre, excluding unknown composers and those who wrote less than 5 songs.

# %%
# %%sql
# -- Write Your Query here

# %% [markdown]
# ## Practice - Write your Own!
# Using any of the other tables in Chinook, write 3 meaningful queries that use GROUP BY to show statistics about the data.
#
# Please include the question your query is designed to answer.

# %% [markdown]
# #### Question 1
# ...

# %%
# %%sql
# -- Write Your Query here

# %% [markdown]
# #### Question 2
# ...

# %%
# %%sql
# -- Write your query here

# %% [markdown]
# #### Question 3
# ...

# %%
# %%sql
# -- Write your query here

# %% [markdown]
# ### Reflection and Questions
#
# What remaining or new questions do you have?
#
# _response_

# %% [markdown]
# ### Submission: Commit and Push your Completed Exercises
